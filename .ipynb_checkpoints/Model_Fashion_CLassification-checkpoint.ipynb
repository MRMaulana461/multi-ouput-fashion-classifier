# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import cv2  # Perlu untuk fungsi pengolahan gambar
from tensorflow.keras.layers import Lambda, GlobalMaxPooling2D, SpatialDropout2D  # Layer tambahan
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.layers import GlobalAveragePooling2D, Concatenate, Add, Activation
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.applications import MobileNetV2
from sklearn.model_selection import train_test_split

# %%
# Configure GPU memory growth to avoid OOM errors
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

# %%
# Improved settings
IMG_SIZE = (256, 256)  # Standard size
BATCH_SIZE = 32  # Keep batch size reasonable
LEARNING_RATE = 5e-5  # Starting learning rate

# %%
# Baca file CSV
df = pd.read_csv('../styles.csv', on_bad_lines='skip')
df_img = pd.read_csv('../images.csv', on_bad_lines='skip')

# %%
df.head()
# Out:
#       id gender masterCategory subCategory  articleType baseColour  season  \
# 0  15970    Men        Apparel     Topwear       Shirts  Navy Blue    Fall
# 1  39386    Men        Apparel  Bottomwear        Jeans       Blue  Summer
# 2  59263  Women    Accessories     Watches      Watches     Silver  Winter
# 3  21379    Men        Apparel  Bottomwear  Track Pants      Black    Fall
# 4  53759    Men        Apparel     Topwear      Tshirts       Grey  Summer
#
#      year   usage                             productDisplayName
# 0  2011.0  Casual               Turtle Check Men Navy Blue Shirt
# 1  2012.0  Casual             Peter England Men Party Blue Jeans
# 2  2016.0  Casual                       Titan Women Silver Watch
# 3  2011.0  Casual  Manchester United Men Solid Black Track Pants
# 4  2012.0  Casual                          Puma Men Grey T-shirt

# %%
df['subCategory'].value_counts().head(10)
# Out:
# subCategory
# Topwear       15402
# Shoes          7343
# Bags           3055
# Bottomwear     2694
# Watches        2542
# Innerwear      1808
# Jewellery      1079
# Eyewear        1073
# Fragrance      1011
# Sandal          963
# Name: count, dtype: int64

# %%
# Membersihkan dan menyiapkan data
df_img['id'] = df_img['filename'].str.replace('.jpg', '', regex=False).astype(int)
df = df.dropna(subset=['gender', 'usage', 'articleType'])

# %%
df['articleType'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='articleType'>

# %%
# Gabungkan gender, category, dan articleType
df['product'] = df['gender'] + ' ' + df['usage'] + ' ' + df['articleType']

# %%
df['product'].value_counts().head(10)
# Out:
# product
# Men Casual Tshirts         4459
# Men Casual Casual Shoes    2218
# Men Casual Shirts          1979
# Women Ethnic Kurtas        1754
# Women Casual Handbags      1679
# Men Sports Sports Shoes    1555
# Women Casual Tops          1470
# Men Casual Watches         1423
# Women Casual Heels         1287
# Women Casual Tshirts        967
# Name: count, dtype: int64

# %%
# Filter hanya produk dengan jumlah yang memadai
product_counts = df['product'].value_counts()
valid_products = product_counts[product_counts >= 1000].index
df_filtered = df[df['product'].isin(valid_products)]

# %%
# Gabungkan dengan data gambar
df_merged = pd.merge(df_img, df_filtered, on='id')
df_merged['image_path'] = '../images/' + df_merged['filename']

# %%
# Hapus baris jika gambar tidak ada
df_merged = df_merged[df_merged['image_path'].apply(os.path.exists)]
df_merged = df_merged.reset_index(drop=True)

# %%
# Definisikan fungsi residual block
def res_block(x, filters, kernel_size=3, stride=1, use_bias=True, name=None):
    shortcut = x
    
    # First convolution
    x = Conv2D(filters, kernel_size, strides=stride, padding='same', use_bias=use_bias, 
               kernel_regularizer=l2(0.001), name=f'{name}_conv1')(x)
    x = BatchNormalization(name=f'{name}_bn1')(x)
    x = Activation('relu', name=f'{name}_relu1')(x)
    
    # Second convolution
    x = Conv2D(filters, kernel_size, padding='same', use_bias=use_bias, 
               kernel_regularizer=l2(0.001), name=f'{name}_conv2')(x)
    x = BatchNormalization(name=f'{name}_bn2')(x)
    
    # Shortcut connection
    if stride > 1 or shortcut.shape[-1] != filters:
        shortcut = Conv2D(filters, 1, strides=stride, padding='same', use_bias=use_bias,
                          kernel_regularizer=l2(0.001), name=f'{name}_shortcut')(shortcut)
        shortcut = BatchNormalization(name=f'{name}_shortcut_bn')(shortcut)
    
    # Add shortcut to output
    x = Add(name=f'{name}_add')([x, shortcut])
    x = Activation('relu', name=f'{name}_relu2')(x)
    
    return x

# %%
# Encode targets
le_gender = LabelEncoder()
le_usage = LabelEncoder()
le_article = LabelEncoder()

df_merged['gender_encoded'] = le_gender.fit_transform(df_merged['gender'])
df_merged['usage_encoded'] = le_usage.fit_transform(df_merged['usage'])
df_merged['article_encoded'] = le_article.fit_transform(df_merged['articleType'])

print(f"Number of gender classes: {len(le_gender.classes_)}")
print(f"Number of usage classes: {len(le_usage.classes_)}")
print(f"Number of article classes: {len(le_article.classes_)}")

# Split data - stratified split for better class balance
train_df, val_df = train_test_split(
    df_merged,
    test_size=0.2,
    stratify=df_merged['gender_encoded'].astype(str) + '_' + 
             df_merged['usage_encoded'].astype(str) + '_' + 
             df_merged['article_encoded'].astype(str),
    random_state=42
)
# Out:
# Number of gender classes: 2
# Number of usage classes: 3
# Number of article classes: 9

# %%
# Definisi helper function untuk multi_output_generator
def multi_output_generator(generator):
    while True:
        batch = next(generator)
        images, labels = batch
        # Ensure labels are numeric
        gender = labels[:, 0].astype(np.int32)
        usage = labels[:, 1].astype(np.int32)
        article = labels[:, 2].astype(np.int32)
        yield images, {'gender': gender, 'usage': usage, 'article': article}

# %%
# Augmentasi data yang ditingkatkan untuk menangani variasi pencahayaan dan kualitas gambar
def create_robust_augmentation_generators():
    def robust_preprocessing(img):
        # Normalisasi standar
        img = (img - np.mean(img)) / (np.std(img) + 1e-7)
        
        # Simulasi gambar berkualitas rendah secara acak
        if np.random.random() < 0.3:  # 30% kemungkinan
            # Tambahkan noise
            noise_level = np.random.uniform(0.01, 0.05)
            noise = np.random.normal(0, noise_level, img.shape)
            img = img + noise
            img = np.clip(img, 0, 1)  # Pastikan nilai tetap valid
            
            # Blur acak
            if np.random.random() < 0.5:
                blur_size = np.random.choice([3, 5])
                img = cv2.GaussianBlur(img, (blur_size, blur_size), 0)
                
            # Kompresi JPEG simulasi
            if np.random.random() < 0.4:
                encode_param = [int(cv2.IMWRITE_JPEG_QUALITY), np.random.randint(40, 90)]
                _, encimg = cv2.imencode('.jpg', (img * 255.0).astype(np.uint8), encode_param)
                img = cv2.imdecode(encimg, 1) / 255.0
        
        # Simulasi variasi pencahayaan
        if np.random.random() < 0.4:  # 40% kemungkinan
            # Kontras acak
            alpha = np.random.uniform(0.6, 1.4)
            img = img * alpha
            
            # Kecerahan acak per channel (simulasi white balance yang berbeda)
            beta = np.random.uniform(0.7, 1.3, size=(1, 1, 3))
            img = img * beta
            
            # Gamma koreksi untuk simulasi kondisi gelap/terang
            gamma = np.random.uniform(0.7, 1.3)
            img = np.power(np.maximum(img, 1e-10), gamma)  # Hindari nilai negatif pada power
        
        # Color jitter (mengubah saturasi dan hue)
        if np.random.random() < 0.3:
            # Pastikan gambar dalam range yang benar dan konversi ke tipe data float32
            img_rgb = np.clip(img, 0, 1).astype(np.float32)
            # Konversi ke HSV
            hsv = cv2.cvtColor(img_rgb, cv2.COLOR_RGB2HSV)
            # Ubah hue
            hsv[:,:,0] = hsv[:,:,0] * np.random.uniform(0.8, 1.2)
            # Ubah saturasi
            hsv[:,:,1] = hsv[:,:,1] * np.random.uniform(0.6, 1.4)
            # Konversi kembali ke RGB
            img = cv2.cvtColor(hsv, cv2.COLOR_HSV2RGB)
            
        # Random occlusion/erasing - simulasi objek tertutup sebagian
        if np.random.random() < 0.2:
            h, w = img.shape[0], img.shape[1]
            area = h * w
            target_area = np.random.uniform(0.02, 0.15) * area
            aspect_ratio = np.random.uniform(0.3, 1/0.3)
            
            # Hitung tinggi dan lebar
            h_occlusion = int(round(np.sqrt(target_area * aspect_ratio)))
            w_occlusion = int(round(np.sqrt(target_area / aspect_ratio)))
            
            if h_occlusion < h and w_occlusion < w:
                x1 = np.random.randint(0, w - w_occlusion)
                y1 = np.random.randint(0, h - h_occlusion)
                
                if len(img.shape) == 3:
                    img[y1:y1+h_occlusion, x1:x1+w_occlusion, :] = np.random.uniform(0, 1, size=(h_occlusion, w_occlusion, img.shape[2]))
                else:
                    img[y1:y1+h_occlusion, x1:x1+w_occlusion] = np.random.uniform(0, 1)
        
        # Pastikan nilai valid
        img = np.clip(img, 0, 1.0)
        return img

    # Generator untuk training dengan augmentasi yang lebih robust
    train_datagen = ImageDataGenerator(
        rescale=1./255,
        rotation_range=20,                # Rotasi moderat untuk pakaian
        zoom_range=0.2,                   # Zoom untuk variasi skala
        width_shift_range=0.2,            # Pergeseran horizontal
        height_shift_range=0.2,           # Pergeseran vertikal
        horizontal_flip=True,             # Flip horizontal
        fill_mode='nearest',
        preprocessing_function=robust_preprocessing
    )

    # Generator untuk validasi dengan normalisasi dasar
    val_datagen = ImageDataGenerator(
        rescale=1./255,
        preprocessing_function=lambda x: (x - np.mean(x)) / (np.std(x) + 1e-7)  # Hanya normalisasi
    )

    return train_datagen, val_datagen

# %%
# Fungsi untuk menerapkan robust augmentation generator
def apply_robust_augmentation():
    # Buat generator dengan augmentasi yang lebih robust
    robust_train_datagen, robust_val_datagen = create_robust_augmentation_generators()
    
    # Konfigurasi generator untuk training
    robust_train_generator_raw = robust_train_datagen.flow_from_dataframe(
        dataframe=train_df,
        x_col='image_path',
        y_col=['gender_encoded', 'usage_encoded', 'article_encoded'],
        target_size=IMG_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='raw',
        shuffle=True
    )
    
    # Konfigurasi generator untuk validasi
    robust_val_generator_raw = robust_val_datagen.flow_from_dataframe(
        dataframe=val_df,
        x_col='image_path',
        y_col=['gender_encoded', 'usage_encoded', 'article_encoded'],
        target_size=IMG_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='raw',
        shuffle=False
    )
    
    # Wrap generator untuk memastikan format output yang tepat
    robust_train_generator = multi_output_generator(robust_train_generator_raw)
    robust_val_generator = multi_output_generator(robust_val_generator_raw)
    
    return robust_train_generator, robust_val_generator

# %%
# Modifikasi pada fungsi build_improved_cnn untuk meningkatkan ketahanan terhadap variasi gambar
def build_robust_cnn(input_shape, n_gender, n_usage, n_article):
    inputs = Input(shape=input_shape)
    
    # Lapisan normalisasi di awal untuk menyeragamkan input
    x = Lambda(lambda x: (x - tf.reduce_mean(x, axis=[1, 2], keepdims=True)) / 
              (tf.math.reduce_std(x, axis=[1, 2], keepdims=True) + 1e-7))(inputs)
    
    # Konvolusi awal dengan filter lebih banyak untuk menangkap fitur lokal
    x = Conv2D(64, (5, 5), strides=(2, 2), padding='same', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    
    # Residual blocks dengan BatchNormalization (lebih stabil untuk batch kecil)
    x = res_block(x, 128, name='res_block1')
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = SpatialDropout2D(0.25)(x)  # Spatial dropout lebih efektif untuk konvolusi
    
    x = res_block(x, 256, name='res_block2')
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = SpatialDropout2D(0.35)(x)
    
    x = res_block(x, 512, name='res_block3')
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = SpatialDropout2D(0.4)(x)
    
    # Feature Pyramid Network style - menggabungkan fitur dari beberapa skala
    # untuk menangkap detail pada berbagai tingkatan
    x1 = GlobalAveragePooling2D()(x)
    x2 = GlobalMaxPooling2D()(x)  # Max pooling untuk menangkap fitur paling menonjol
    x = Concatenate()([x1, x2])
    
    # Fully connected dengan dropout yang lebih tinggi
    x = Dense(512, kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.5)(x)
    
    # Task-specific branches
    gender_branch = Dense(128, activation='relu', kernel_regularizer=l2(0.001))(x)
    gender_branch = BatchNormalization()(gender_branch)
    gender_branch = Dropout(0.4)(gender_branch)
    gender_output = Dense(n_gender, activation='softmax', name='gender')(gender_branch)
    
    usage_branch = Dense(128, activation='relu', kernel_regularizer=l2(0.001))(x)
    usage_branch = BatchNormalization()(usage_branch)
    usage_branch = Dropout(0.4)(usage_branch)
    usage_output = Dense(n_usage, activation='softmax', name='usage')(usage_branch)
    
    article_branch = Dense(256, activation='relu', kernel_regularizer=l2(0.001))(x)
    article_branch = BatchNormalization()(article_branch)
    article_branch = Dropout(0.5)(article_branch)
    article_output = Dense(n_article, activation='softmax', name='article')(article_branch)
    
    model = Model(inputs=inputs, outputs=[gender_output, usage_output, article_output])
    return model

# %%
# Fungsi untuk melatih model dengan augmentasi robust
def train_with_robust_augmentation():
    # Buat model yang robust
    robust_model = build_robust_cnn(
        (IMG_SIZE[0], IMG_SIZE[1], 3),
        n_gender=len(le_gender.classes_),
        n_usage=len(le_usage.classes_),
        n_article=len(le_article.classes_)
    )
    
    # Generator dengan augmentasi robust
    robust_train_generator, robust_val_generator = apply_robust_augmentation()
    
    # Compile model dengan optimizer yang lebih robust
    optimizer = Adam(learning_rate=1e-3, clipnorm=1.0)  # Clip gradien untuk stabilitas
    
    robust_model.compile(
        optimizer=optimizer,
        loss={
            'gender': 'sparse_categorical_crossentropy',
            'usage': 'sparse_categorical_crossentropy',
            'article': 'sparse_categorical_crossentropy'
        },
        metrics=['accuracy'],
        loss_weights={
            'gender': 2.0, 
            'usage': 1.0, 
            'article': 2.0
        }
    )
    
    # Callbacks untuk mencegah overfitting
    robust_callbacks = [
        ModelCheckpoint(
            'best_robust_model.h5', 
            monitor='val_loss', 
            save_best_only=True, 
            mode='min', 
            verbose=1
        ),
        EarlyStopping(
            monitor='val_loss', 
            patience=15,  # Lebih sabar
            restore_best_weights=True, 
            verbose=1,
            min_delta=0.005
        ),
        ReduceLROnPlateau(
            monitor='val_loss', 
            factor=0.5, 
            patience=5,
            min_lr=1e-6, 
            verbose=1
        )
    ]
    
    # Membagi epochs training menjadi dua tahap
    print("\n===== TRAINING ROBUST CNN MODEL DENGAN AUGMENTASI LANJUTAN =====")
    steps_per_epoch = len(train_df) // BATCH_SIZE
    validation_steps = len(val_df) // BATCH_SIZE
    
    # Tahap 1: Latih model dengan learning rate yang tinggi
    print("\n--- Tahap 1: Initial Training ---")
    initial_history = robust_model.fit(
        robust_train_generator,
        steps_per_epoch=steps_per_epoch,
        validation_data=robust_val_generator,
        validation_steps=validation_steps,
        epochs=30,
        callbacks=robust_callbacks,
        verbose=1
    )
    
    # Tahap 2: Fine-tuning dengan learning rate lebih rendah
    print("\n--- Tahap 2: Fine Tuning ---")
    # Atur ulang optimizer dengan learning rate lebih rendah
    K = tf.keras.backend
    K.set_value(robust_model.optimizer.learning_rate, 1e-4)
    
    fine_tune_history = robust_model.fit(
        robust_train_generator,
        steps_per_epoch=steps_per_epoch,
        validation_data=robust_val_generator,
        validation_steps=validation_steps,
        epochs=70,  # Tambahan epoch untuk fine-tuning
        callbacks=robust_callbacks,
        verbose=1
    )
    
    # Gabungkan history
    combined_history = {
        'loss': initial_history.history['loss'] + fine_tune_history.history['loss'],
        'val_loss': initial_history.history['val_loss'] + fine_tune_history.history['val_loss'],
        'gender_accuracy': initial_history.history['gender_accuracy'] + fine_tune_history.history['gender_accuracy'],
        'val_gender_accuracy': initial_history.history['val_gender_accuracy'] + fine_tune_history.history['val_gender_accuracy'],
        'usage_accuracy': initial_history.history['usage_accuracy'] + fine_tune_history.history['usage_accuracy'],
        'val_usage_accuracy': initial_history.history['val_usage_accuracy'] + fine_tune_history.history['val_usage_accuracy'],
        'article_accuracy': initial_history.history['article_accuracy'] + fine_tune_history.history['article_accuracy'],
        'val_article_accuracy': initial_history.history['val_article_accuracy'] + fine_tune_history.history['val_article_accuracy']
    }
    
    return robust_model, combined_history

# %%
# Fungsi untuk evaluasi model pada gambar yang berkualitas rendah
def evaluate_on_degraded_images(model, val_generator, val_steps):
    # Generator untuk evaluasi dengan simulasi gambar berkualitas rendah
    def degrade_image(img):
        # Normalisasi standar
        img = (img - np.mean(img)) / (np.std(img) + 1e-7)
        
        # Ciptakan kondisi ekstrem (lebih dari yang dilatih)
        # Tambahkan noise tingkat tinggi
        noise = np.random.normal(0, 0.1, img.shape)
        img = img + noise
        
        # Tambahkan blur yang kuat
        img = cv2.GaussianBlur(img, (7, 7), 0)
        
        # Simulasi pencahayaan yang buruk
        brightness_factor = np.random.uniform(0.4, 0.7)
        img = img * brightness_factor
        
        # Simulasi kualitas kompresi rendah
        encode_param = [int(cv2.IMWRITE_JPEG_QUALITY), 30]  # Kualitas sangat rendah
        img_uint8 = (np.clip(img, 0, 1) * 255).astype(np.uint8)
        _, encimg = cv2.imencode('.jpg', img_uint8, encode_param)
        img = cv2.imdecode(encimg, 1) / 255.0
        
        # Normalisasi kembali
        img = (img - np.mean(img)) / (np.std(img) + 1e-7)
        img = np.clip(img, 0, 1.0)
        return img
    
    # Buat generator untuk evaluasi dengan gambar berkualitas rendah
    eval_datagen = ImageDataGenerator(
        rescale=1./255,
        preprocessing_function=degrade_image
    )
    
    # Konfigurasi generator evaluasi
    eval_generator_raw = eval_datagen.flow_from_dataframe(
        dataframe=val_df,
        x_col='image_path',
        y_col=['gender_encoded', 'usage_encoded', 'article_encoded'],
        target_size=IMG_SIZE,
        batch_size=BATCH_SIZE,
        class_mode='raw',
        shuffle=False
    )
    
    eval_generator = multi_output_generator(eval_generator_raw)
    
    # Evaluasi model
    print("\n===== EVALUASI MODEL PADA GAMBAR BERKUALITAS RENDAH =====")
    results = model.evaluate(
        eval_generator,
        steps=val_steps,
        verbose=1
    )
    
    # Cetak hasil evaluasi
    print(f"\nLoss: {results[0]}")
    print(f"Gender Accuracy: {results[4] * 100:.2f}%")
    print(f"Usage Accuracy: {results[5] * 100:.2f}%")
    print(f"Article Accuracy: {results[6] * 100:.2f}%")
    
    return results

# %%
# Fungsi untuk visualisasi augmentasi
def visualize_augmentations():
    # Ambil beberapa gambar sampel
    sample_images = []
    sample_labels = []
    
    # Ambil beberapa sampel dari validation set
    val_generator_vis = ImageDataGenerator(rescale=1./255).flow_from_dataframe(
        dataframe=val_df.sample(5),
        x_col='image_path',
        y_col=['gender_encoded', 'usage_encoded', 'article_encoded'],
        target_size=IMG_SIZE,
        batch_size=5,
        class_mode='raw',
        shuffle=False
    )
    
    # Ambil batch pertama
    images, labels = next(val_generator_vis)
    
    # Dapatkan fungsi preprocessing robust
    _, _ = create_robust_augmentation_generators()
    
    # Fungsi untuk mengambil fungsi preprocessing dari train_datagen
    def get_preprocessing_function():
        def robust_preprocessing(img):
            # Normalisasi standar
            img = (img - np.mean(img)) / (np.std(img) + 1e-7)
            
            # Simulasi gambar berkualitas rendah secara acak
            if True:  # Selalu lakukan untuk visualisasi
                # Tambahkan noise
                noise_level = np.random.uniform(0.01, 0.05)
                noise = np.random.normal(0, noise_level, img.shape)
                img = img + noise
                img = np.clip(img, 0, 1)  # Pastikan nilai tetap valid
                
                # Blur acak
                if True:
                    blur_size = np.random.choice([3, 5])
                    img = cv2.GaussianBlur(img, (blur_size, blur_size), 0)
                    
                # Kompresi JPEG simulasi
                if True:
                    encode_param = [int(cv2.IMWRITE_JPEG_QUALITY), np.random.randint(40, 90)]
                    img_uint8 = (np.clip(img, 0, 1) * 255).astype(np.uint8)
                    _, encimg = cv2.imencode('.jpg', img_uint8, encode_param)
                    img = cv2.imdecode(encimg, 1) / 255.0
            
            # Simulasi variasi pencahayaan
            if True:  # Selalu lakukan untuk visualisasi
                # Kontras acak
                alpha = np.random.uniform(0.6, 1.4)
                img = img * alpha
                
                # Kecerahan acak per channel (simulasi white balance yang berbeda)
                beta = np.random.uniform(0.7, 1.3, size=(1, 1, 3))
                img = img * beta
                
                # Gamma koreksi untuk simulasi kondisi gelap/terang
                gamma = np.random.uniform(0.7, 1.3)
                img = np.power(np.clip(img, 1e-10, 1.0), gamma)
            
            # Pastikan nilai valid
            img = np.clip(img, 0, 1.0)
            return img
        
        return robust_preprocessing
    
    # Dapatkan fungsi preprocessing
    robust_preprocess = get_preprocessing_function()
    
    # Plot original dan augmented images
    plt.figure(figsize=(15, 10))
    
    for i in range(5):
        # Original image
        plt.subplot(5, 3, i*3 + 1)
        plt.imshow(images[i])
        plt.title(f'Original {i+1}')
        plt.axis('off')
        
        # Augmented image 1
        aug_img1 = robust_preprocess(images[i].copy())
        plt.subplot(5, 3, i*3 + 2)
        plt.imshow(np.clip(aug_img1, 0, 1))
        plt.title(f'Augmented 1 {i+1}')
        plt.axis('off')
        
        # Augmented image 2
        aug_img2 = robust_preprocess(images[i].copy())
        plt.subplot(5, 3, i*3 + 3)
        plt.imshow(np.clip(aug_img2, 0, 1))
        plt.title(f'Augmented 2 {i+1}')
        plt.axis('off')
    
    plt.tight_layout()
    plt.savefig('augmentation_visualization.png')
    plt.show()

# %%
# Train model dengan augmentasi robust
robust_model, robust_history = train_with_robust_augmentation()
    
# Simpan model
robust_model.save('fashion_classifier_robust.h5')
# Out:
# Found 13979 validated image filenames.
# Found 3495 validated image filenames.
#
# ===== TRAINING ROBUST CNN MODEL DENGAN AUGMENTASI LANJUTAN =====
#
# --- Tahap 1: Initial Training ---
# Epoch 1/30
# 436/436 [==============================] - ETA: 0s - loss: 9.8342 - gender_loss: 0.7395 - usage_loss: 0.7808 - article_loss: 2.0654 - gender_accuracy: 0.6565 - usage_accuracy: 0.6973 - article_accuracy: 0.3283
# Epoch 1: val_loss improved from inf to 8.42617, saving model to best_robust_model.h5
# 436/436 [==============================] - 475s 1s/step - loss: 9.8342 - gender_loss: 0.7395 - usage_loss: 0.7808 - article_loss: 2.0654 - gender_accuracy: 0.6565 - usage_accuracy: 0.6973 - article_accuracy: 0.3283 - val_loss: 8.4262 - val_gender_loss: 0.6281 - val_usage_loss: 0.8725 - val_article_loss: 1.6969 - val_gender_accuracy: 0.7268 - val_usage_accuracy: 0.8354 - val_article_accuracy: 0.4498 - lr: 0.0010
# Epoch 2/30
# 436/436 [==============================] - ETA: 0s - loss: 6.2837 - gender_loss: 0.3988 - usage_loss: 0.4355 - article_loss: 1.1924 - gender_accuracy: 0.8267 - usage_accuracy: 0.8153 - article_accuracy: 0.5476
# Epoch 2: val_loss improved from 8.42617 to 5.41382, saving model to best_robust_model.h5
# 436/436 [==============================] - 467s 1s/step - loss: 6.2837 - gender_loss: 0.3988 - usage_loss: 0.4355 - article_loss: 1.1924 - gender_accuracy: 0.8267 - usage_accuracy: 0.8153 - article_accuracy: 0.5476 - val_loss: 5.4138 - val_gender_loss: 0.3384 - val_usage_loss: 0.3710 - val_article_loss: 0.9547 - val_gender_accuracy: 0.8604 - val_usage_accuracy: 0.8581 - val_article_accuracy: 0.6626 - lr: 0.0010
# Epoch 3/30
# 436/436 [==============================] - ETA: 0s - loss: 5.1944 - gender_loss: 0.3029 - usage_loss: 0.3655 - article_loss: 0.9502 - gender_accuracy: 0.8762 - usage_accuracy: 0.8331 - article_accuracy: 0.6201
# Epoch 3: val_loss improved from 5.41382 to 5.12414, saving model to best_robust_model.h5
# 436/436 [==============================] - 458s 1s/step - loss: 5.1944 - gender_loss: 0.3029 - usage_loss: 0.3655 - article_loss: 0.9502 - gender_accuracy: 0.8762 - usage_accuracy: 0.8331 - article_accuracy: 0.6201 - val_loss: 5.1241 - val_gender_loss: 0.3294 - val_usage_loss: 0.3819 - val_article_loss: 0.9451 - val_gender_accuracy: 0.8572 - val_usage_accuracy: 0.8397 - val_article_accuracy: 0.6557 - lr: 0.0010
# Epoch 4/30
# 436/436 [==============================] - ETA: 0s - loss: 4.5908 - gender_loss: 0.2493 - usage_loss: 0.3334 - article_loss: 0.8271 - gender_accuracy: 0.9004 - usage_accuracy: 0.8408 - article_accuracy: 0.6694
# Epoch 4: val_loss improved from 5.12414 to 4.38382, saving model to best_robust_model.h5
# 436/436 [==============================] - 457s 1s/step - loss: 4.5908 - gender_loss: 0.2493 - usage_loss: 0.3334 - article_loss: 0.8271 - gender_accuracy: 0.9004 - usage_accuracy: 0.8408 - article_accuracy: 0.6694 - val_loss: 4.3838 - val_gender_loss: 0.2609 - val_usage_loss: 0.3149 - val_article_loss: 0.7709 - val_gender_accuracy: 0.9022 - val_usage_accuracy: 0.8827 - val_article_accuracy: 0.7302 - lr: 0.0010
# Epoch 5/30
# 436/436 [==============================] - ETA: 0s - loss: 4.1687 - gender_loss: 0.2218 - usage_loss: 0.3109 - article_loss: 0.7492 - gender_accuracy: 0.9156 - usage_accuracy: 0.8479 - article_accuracy: 0.7025
# Epoch 5: val_loss did not improve from 4.38382
# 436/436 [==============================] - 463s 1s/step - loss: 4.1687 - gender_loss: 0.2218 - usage_loss: 0.3109 - article_loss: 0.7492 - gender_accuracy: 0.9156 - usage_accuracy: 0.8479 - article_accuracy: 0.7025 - val_loss: 4.5559 - val_gender_loss: 0.3768 - val_usage_loss: 0.3213 - val_article_loss: 0.8080 - val_gender_accuracy: 0.8555 - val_usage_accuracy: 0.8592 - val_article_accuracy: 0.6666 - lr: 0.0010
# Epoch 6/30
# 436/436 [==============================] - ETA: 0s - loss: 3.9613 - gender_loss: 0.1994 - usage_loss: 0.3069 - article_loss: 0.7138 - gender_accuracy: 0.9230 - usage_accuracy: 0.8563 - article_accuracy: 0.7194
# Epoch 6: val_loss improved from 4.38382 to 3.97798, saving model to best_robust_model.h5
# 436/436 [==============================] - 435s 999ms/step - loss: 3.9613 - gender_loss: 0.1994 - usage_loss: 0.3069 - article_loss: 0.7138 - gender_accuracy: 0.9230 - usage_accuracy: 0.8563 - article_accuracy: 0.7194 - val_loss: 3.9780 - val_gender_loss: 0.2478 - val_usage_loss: 0.2618 - val_article_loss: 0.7119 - val_gender_accuracy: 0.9019 - val_usage_accuracy: 0.8870 - val_article_accuracy: 0.7165 - lr: 0.0010
# Epoch 7/30
# 436/436 [==============================] - ETA: 0s - loss: 3.7998 - gender_loss: 0.1920 - usage_loss: 0.2990 - article_loss: 0.6815 - gender_accuracy: 0.9264 - usage_accuracy: 0.8596 - article_accuracy: 0.7283
# Epoch 7: val_loss did not improve from 3.97798
# 436/436 [==============================] - 414s 950ms/step - loss: 3.7998 - gender_loss: 0.1920 - usage_loss: 0.2990 - article_loss: 0.6815 - gender_accuracy: 0.9264 - usage_accuracy: 0.8596 - article_accuracy: 0.7283 - val_loss: 4.2643 - val_gender_loss: 0.3062 - val_usage_loss: 0.2815 - val_article_loss: 0.8224 - val_gender_accuracy: 0.8638 - val_usage_accuracy: 0.8905 - val_article_accuracy: 0.6884 - lr: 0.0010
# Epoch 8/30
# 436/436 [==============================] - ETA: 0s - loss: 3.6672 - gender_loss: 0.1824 - usage_loss: 0.2849 - article_loss: 0.6560 - gender_accuracy: 0.9320 - usage_accuracy: 0.8651 - article_accuracy: 0.7379
# Epoch 8: val_loss improved from 3.97798 to 3.27216, saving model to best_robust_model.h5
# 436/436 [==============================] - 408s 938ms/step - loss: 3.6672 - gender_loss: 0.1824 - usage_loss: 0.2849 - article_loss: 0.6560 - gender_accuracy: 0.9320 - usage_accuracy: 0.8651 - article_accuracy: 0.7379 - val_loss: 3.2722 - val_gender_loss: 0.1526 - val_usage_loss: 0.2401 - val_article_loss: 0.5171 - val_gender_accuracy: 0.9375 - val_usage_accuracy: 0.8807 - val_article_accuracy: 0.7835 - lr: 0.0010
# Epoch 9/30
# 436/436 [==============================] - ETA: 0s - loss: 3.5707 - gender_loss: 0.1773 - usage_loss: 0.2777 - article_loss: 0.6330 - gender_accuracy: 0.9323 - usage_accuracy: 0.8660 - article_accuracy: 0.7512
# Epoch 9: val_loss did not improve from 3.27216
# 436/436 [==============================] - 409s 940ms/step - loss: 3.5707 - gender_loss: 0.1773 - usage_loss: 0.2777 - article_loss: 0.6330 - gender_accuracy: 0.9323 - usage_accuracy: 0.8660 - article_accuracy: 0.7512 - val_loss: 3.3018 - val_gender_loss: 0.1752 - val_usage_loss: 0.2364 - val_article_loss: 0.5299 - val_gender_accuracy: 0.9335 - val_usage_accuracy: 0.8825 - val_article_accuracy: 0.7790 - lr: 0.0010
# Epoch 10/30
# 436/436 [==============================] - ETA: 0s - loss: 3.4632 - gender_loss: 0.1730 - usage_loss: 0.2753 - article_loss: 0.6138 - gender_accuracy: 0.9348 - usage_accuracy: 0.8683 - article_accuracy: 0.7559
# Epoch 10: val_loss improved from 3.27216 to 3.27086, saving model to best_robust_model.h5
# 436/436 [==============================] - 408s 937ms/step - loss: 3.4632 - gender_loss: 0.1730 - usage_loss: 0.2753 - article_loss: 0.6138 - gender_accuracy: 0.9348 - usage_accuracy: 0.8683 - article_accuracy: 0.7559 - val_loss: 3.2709 - val_gender_loss: 0.1607 - val_usage_loss: 0.2339 - val_article_loss: 0.5540 - val_gender_accuracy: 0.9372 - val_usage_accuracy: 0.8827 - val_article_accuracy: 0.7801 - lr: 0.0010
# Epoch 11/30
# 436/436 [==============================] - ETA: 0s - loss: 3.3872 - gender_loss: 0.1699 - usage_loss: 0.2691 - article_loss: 0.5995 - gender_accuracy: 0.9348 - usage_accuracy: 0.8714 - article_accuracy: 0.7588
# Epoch 11: val_loss did not improve from 3.27086
# 436/436 [==============================] - 407s 936ms/step - loss: 3.3872 - gender_loss: 0.1699 - usage_loss: 0.2691 - article_loss: 0.5995 - gender_accuracy: 0.9348 - usage_accuracy: 0.8714 - article_accuracy: 0.7588 - val_loss: 3.3990 - val_gender_loss: 0.2253 - val_usage_loss: 0.2366 - val_article_loss: 0.5852 - val_gender_accuracy: 0.9100 - val_usage_accuracy: 0.8899 - val_article_accuracy: 0.7821 - lr: 0.0010
# Epoch 12/30
# 436/436 [==============================] - ETA: 0s - loss: 3.3146 - gender_loss: 0.1642 - usage_loss: 0.2665 - article_loss: 0.5842 - gender_accuracy: 0.9403 - usage_accuracy: 0.8736 - article_accuracy: 0.7632
# Epoch 12: val_loss did not improve from 3.27086
# 436/436 [==============================] - 408s 937ms/step - loss: 3.3146 - gender_loss: 0.1642 - usage_loss: 0.2665 - article_loss: 0.5842 - gender_accuracy: 0.9403 - usage_accuracy: 0.8736 - article_accuracy: 0.7632 - val_loss: 3.4283 - val_gender_loss: 0.1896 - val_usage_loss: 0.2615 - val_article_loss: 0.6216 - val_gender_accuracy: 0.9252 - val_usage_accuracy: 0.8713 - val_article_accuracy: 0.7856 - lr: 0.0010
# Epoch 13/30
# 436/436 [==============================] - ETA: 0s - loss: 3.2379 - gender_loss: 0.1566 - usage_loss: 0.2647 - article_loss: 0.5704 - gender_accuracy: 0.9403 - usage_accuracy: 0.8708 - article_accuracy: 0.7725
# Epoch 13: val_loss did not improve from 3.27086
# 436/436 [==============================] - 406s 934ms/step - loss: 3.2379 - gender_loss: 0.1566 - usage_loss: 0.2647 - article_loss: 0.5704 - gender_accuracy: 0.9403 - usage_accuracy: 0.8708 - article_accuracy: 0.7725 - val_loss: 3.3839 - val_gender_loss: 0.2604 - val_usage_loss: 0.2308 - val_article_loss: 0.5667 - val_gender_accuracy: 0.8951 - val_usage_accuracy: 0.9048 - val_article_accuracy: 0.7973 - lr: 0.0010
# Epoch 14/30
# 436/436 [==============================] - ETA: 0s - loss: 3.2140 - gender_loss: 0.1611 - usage_loss: 0.2613 - article_loss: 0.5643 - gender_accuracy: 0.9398 - usage_accuracy: 0.8788 - article_accuracy: 0.7769
# Epoch 14: val_loss improved from 3.27086 to 3.03202, saving model to best_robust_model.h5
# 436/436 [==============================] - 409s 941ms/step - loss: 3.2140 - gender_loss: 0.1611 - usage_loss: 0.2613 - article_loss: 0.5643 - gender_accuracy: 0.9398 - usage_accuracy: 0.8788 - article_accuracy: 0.7769 - val_loss: 3.0320 - val_gender_loss: 0.1593 - val_usage_loss: 0.2163 - val_article_loss: 0.5043 - val_gender_accuracy: 0.9355 - val_usage_accuracy: 0.9065 - val_article_accuracy: 0.7999 - lr: 0.0010
# Epoch 15/30
# 436/436 [==============================] - ETA: 0s - loss: 3.0805 - gender_loss: 0.1467 - usage_loss: 0.2520 - article_loss: 0.5319 - gender_accuracy: 0.9449 - usage_accuracy: 0.8752 - article_accuracy: 0.7868
# Epoch 15: val_loss did not improve from 3.03202
# 436/436 [==============================] - 408s 938ms/step - loss: 3.0805 - gender_loss: 0.1467 - usage_loss: 0.2520 - article_loss: 0.5319 - gender_accuracy: 0.9449 - usage_accuracy: 0.8752 - article_accuracy: 0.7868 - val_loss: 4.2703 - val_gender_loss: 0.3609 - val_usage_loss: 0.3014 - val_article_loss: 0.9063 - val_gender_accuracy: 0.8486 - val_usage_accuracy: 0.8945 - val_article_accuracy: 0.7004 - lr: 0.0010
# Epoch 16/30
# 436/436 [==============================] - ETA: 0s - loss: 3.0156 - gender_loss: 0.1442 - usage_loss: 0.2432 - article_loss: 0.5227 - gender_accuracy: 0.9458 - usage_accuracy: 0.8850 - article_accuracy: 0.7922
# Epoch 16: val_loss improved from 3.03202 to 2.72773, saving model to best_robust_model.h5
# 436/436 [==============================] - 406s 934ms/step - loss: 3.0156 - gender_loss: 0.1442 - usage_loss: 0.2432 - article_loss: 0.5227 - gender_accuracy: 0.9458 - usage_accuracy: 0.8850 - article_accuracy: 0.7922 - val_loss: 2.7277 - val_gender_loss: 0.1360 - val_usage_loss: 0.2126 - val_article_loss: 0.4113 - val_gender_accuracy: 0.9478 - val_usage_accuracy: 0.9031 - val_article_accuracy: 0.8357 - lr: 0.0010
# Epoch 17/30
# 436/436 [==============================] - ETA: 0s - loss: 2.9856 - gender_loss: 0.1435 - usage_loss: 0.2510 - article_loss: 0.5205 - gender_accuracy: 0.9463 - usage_accuracy: 0.8801 - article_accuracy: 0.7902
# Epoch 17: val_loss did not improve from 2.72773
# 436/436 [==============================] - 409s 939ms/step - loss: 2.9856 - gender_loss: 0.1435 - usage_loss: 0.2510 - article_loss: 0.5205 - gender_accuracy: 0.9463 - usage_accuracy: 0.8801 - article_accuracy: 0.7902 - val_loss: 3.3621 - val_gender_loss: 0.2506 - val_usage_loss: 0.2492 - val_article_loss: 0.6087 - val_gender_accuracy: 0.8827 - val_usage_accuracy: 0.9074 - val_article_accuracy: 0.7838 - lr: 0.0010
# Epoch 18/30
# 436/436 [==============================] - ETA: 0s - loss: 2.9539 - gender_loss: 0.1420 - usage_loss: 0.2464 - article_loss: 0.5161 - gender_accuracy: 0.9479 - usage_accuracy: 0.8854 - article_accuracy: 0.7954
# Epoch 18: val_loss did not improve from 2.72773
# 436/436 [==============================] - 412s 947ms/step - loss: 2.9539 - gender_loss: 0.1420 - usage_loss: 0.2464 - article_loss: 0.5161 - gender_accuracy: 0.9479 - usage_accuracy: 0.8854 - article_accuracy: 0.7954 - val_loss: 3.3923 - val_gender_loss: 0.3066 - val_usage_loss: 0.2410 - val_article_loss: 0.5865 - val_gender_accuracy: 0.8604 - val_usage_accuracy: 0.8942 - val_article_accuracy: 0.7767 - lr: 0.0010
# Epoch 19/30
# 436/436 [==============================] - ETA: 0s - loss: 2.8932 - gender_loss: 0.1363 - usage_loss: 0.2476 - article_loss: 0.5053 - gender_accuracy: 0.9497 - usage_accuracy: 0.8832 - article_accuracy: 0.7962
# Epoch 19: val_loss did not improve from 2.72773
# 436/436 [==============================] - 411s 944ms/step - loss: 2.8932 - gender_loss: 0.1363 - usage_loss: 0.2476 - article_loss: 0.5053 - gender_accuracy: 0.9497 - usage_accuracy: 0.8832 - article_accuracy: 0.7962 - val_loss: 3.0513 - val_gender_loss: 0.2031 - val_usage_loss: 0.2217 - val_article_loss: 0.5329 - val_gender_accuracy: 0.9128 - val_usage_accuracy: 0.9106 - val_article_accuracy: 0.8286 - lr: 0.0010
# Epoch 20/30
# 436/436 [==============================] - ETA: 0s - loss: 2.8502 - gender_loss: 0.1331 - usage_loss: 0.2407 - article_loss: 0.4990 - gender_accuracy: 0.9503 - usage_accuracy: 0.8836 - article_accuracy: 0.7995
# Epoch 20: val_loss did not improve from 2.72773
# 436/436 [==============================] - 410s 943ms/step - loss: 2.8502 - gender_loss: 0.1331 - usage_loss: 0.2407 - article_loss: 0.4990 - gender_accuracy: 0.9503 - usage_accuracy: 0.8836 - article_accuracy: 0.7995 - val_loss: 2.7439 - val_gender_loss: 0.1213 - val_usage_loss: 0.2673 - val_article_loss: 0.4457 - val_gender_accuracy: 0.9541 - val_usage_accuracy: 0.8807 - val_article_accuracy: 0.8268 - lr: 0.0010
# Epoch 21/30
# 436/436 [==============================] - ETA: 0s - loss: 2.8027 - gender_loss: 0.1307 - usage_loss: 0.2394 - article_loss: 0.4879 - gender_accuracy: 0.9522 - usage_accuracy: 0.8848 - article_accuracy: 0.8018
# Epoch 21: val_loss improved from 2.72773 to 2.68989, saving model to best_robust_model.h5
# 436/436 [==============================] - 413s 949ms/step - loss: 2.8027 - gender_loss: 0.1307 - usage_loss: 0.2394 - article_loss: 0.4879 - gender_accuracy: 0.9522 - usage_accuracy: 0.8848 - article_accuracy: 0.8018 - val_loss: 2.6899 - val_gender_loss: 0.1407 - val_usage_loss: 0.2297 - val_article_loss: 0.4398 - val_gender_accuracy: 0.9381 - val_usage_accuracy: 0.9045 - val_article_accuracy: 0.8254 - lr: 0.0010
# Epoch 22/30
# 436/436 [==============================] - ETA: 0s - loss: 2.7802 - gender_loss: 0.1337 - usage_loss: 0.2366 - article_loss: 0.4855 - gender_accuracy: 0.9515 - usage_accuracy: 0.8880 - article_accuracy: 0.8040
# Epoch 22: val_loss did not improve from 2.68989
# 436/436 [==============================] - 413s 948ms/step - loss: 2.7802 - gender_loss: 0.1337 - usage_loss: 0.2366 - article_loss: 0.4855 - gender_accuracy: 0.9515 - usage_accuracy: 0.8880 - article_accuracy: 0.8040 - val_loss: 2.6950 - val_gender_loss: 0.1365 - val_usage_loss: 0.2280 - val_article_loss: 0.4512 - val_gender_accuracy: 0.9478 - val_usage_accuracy: 0.8856 - val_article_accuracy: 0.8128 - lr: 0.0010
# Epoch 23/30
# 436/436 [==============================] - ETA: 0s - loss: 2.7294 - gender_loss: 0.1317 - usage_loss: 0.2322 - article_loss: 0.4777 - gender_accuracy: 0.9535 - usage_accuracy: 0.8938 - article_accuracy: 0.8126
# Epoch 23: val_loss improved from 2.68989 to 2.58074, saving model to best_robust_model.h5
# 436/436 [==============================] - 415s 954ms/step - loss: 2.7294 - gender_loss: 0.1317 - usage_loss: 0.2322 - article_loss: 0.4777 - gender_accuracy: 0.9535 - usage_accuracy: 0.8938 - article_accuracy: 0.8126 - val_loss: 2.5807 - val_gender_loss: 0.1214 - val_usage_loss: 0.1964 - val_article_loss: 0.4362 - val_gender_accuracy: 0.9536 - val_usage_accuracy: 0.9166 - val_article_accuracy: 0.8435 - lr: 0.0010
# Epoch 24/30
# 436/436 [==============================] - ETA: 0s - loss: 2.6945 - gender_loss: 0.1264 - usage_loss: 0.2363 - article_loss: 0.4707 - gender_accuracy: 0.9530 - usage_accuracy: 0.8862 - article_accuracy: 0.8109
# Epoch 24: val_loss improved from 2.58074 to 2.47295, saving model to best_robust_model.h5
# 436/436 [==============================] - 414s 951ms/step - loss: 2.6945 - gender_loss: 0.1264 - usage_loss: 0.2363 - article_loss: 0.4707 - gender_accuracy: 0.9530 - usage_accuracy: 0.8862 - article_accuracy: 0.8109 - val_loss: 2.4730 - val_gender_loss: 0.1443 - val_usage_loss: 0.1820 - val_article_loss: 0.3685 - val_gender_accuracy: 0.9447 - val_usage_accuracy: 0.9177 - val_article_accuracy: 0.8598 - lr: 0.0010
# Epoch 25/30
# 436/436 [==============================] - ETA: 0s - loss: 2.6546 - gender_loss: 0.1234 - usage_loss: 0.2296 - article_loss: 0.4588 - gender_accuracy: 0.9545 - usage_accuracy: 0.8910 - article_accuracy: 0.8172
# Epoch 25: val_loss did not improve from 2.47295
# 436/436 [==============================] - 416s 956ms/step - loss: 2.6546 - gender_loss: 0.1234 - usage_loss: 0.2296 - article_loss: 0.4588 - gender_accuracy: 0.9545 - usage_accuracy: 0.8910 - article_accuracy: 0.8172 - val_loss: 2.8460 - val_gender_loss: 0.1917 - val_usage_loss: 0.2080 - val_article_loss: 0.4992 - val_gender_accuracy: 0.9226 - val_usage_accuracy: 0.9140 - val_article_accuracy: 0.8254 - lr: 0.0010
# Epoch 26/30
# 436/436 [==============================] - ETA: 0s - loss: 2.6470 - gender_loss: 0.1249 - usage_loss: 0.2276 - article_loss: 0.4621 - gender_accuracy: 0.9538 - usage_accuracy: 0.8958 - article_accuracy: 0.8167
# Epoch 26: val_loss did not improve from 2.47295
# 436/436 [==============================] - 418s 960ms/step - loss: 2.6470 - gender_loss: 0.1249 - usage_loss: 0.2276 - article_loss: 0.4621 - gender_accuracy: 0.9538 - usage_accuracy: 0.8958 - article_accuracy: 0.8167 - val_loss: 2.6649 - val_gender_loss: 0.1359 - val_usage_loss: 0.2173 - val_article_loss: 0.4604 - val_gender_accuracy: 0.9404 - val_usage_accuracy: 0.9074 - val_article_accuracy: 0.8245 - lr: 0.0010
# Epoch 27/30
# 436/436 [==============================] - ETA: 0s - loss: 2.5966 - gender_loss: 0.1158 - usage_loss: 0.2300 - article_loss: 0.4490 - gender_accuracy: 0.9565 - usage_accuracy: 0.8918 - article_accuracy: 0.8204
# Epoch 27: val_loss did not improve from 2.47295
# 436/436 [==============================] - 422s 969ms/step - loss: 2.5966 - gender_loss: 0.1158 - usage_loss: 0.2300 - article_loss: 0.4490 - gender_accuracy: 0.9565 - usage_accuracy: 0.8918 - article_accuracy: 0.8204 - val_loss: 3.6166 - val_gender_loss: 0.3661 - val_usage_loss: 0.2526 - val_article_loss: 0.6983 - val_gender_accuracy: 0.8541 - val_usage_accuracy: 0.9106 - val_article_accuracy: 0.7838 - lr: 0.0010
# Epoch 28/30
# 436/436 [==============================] - ETA: 0s - loss: 2.5605 - gender_loss: 0.1186 - usage_loss: 0.2261 - article_loss: 0.4397 - gender_accuracy: 0.9577 - usage_accuracy: 0.8915 - article_accuracy: 0.8223
# Epoch 28: val_loss improved from 2.47295 to 2.27220, saving model to best_robust_model.h5
# 436/436 [==============================] - 422s 969ms/step - loss: 2.5605 - gender_loss: 0.1186 - usage_loss: 0.2261 - article_loss: 0.4397 - gender_accuracy: 0.9577 - usage_accuracy: 0.8915 - article_accuracy: 0.8223 - val_loss: 2.2722 - val_gender_loss: 0.0959 - val_usage_loss: 0.1853 - val_article_loss: 0.3483 - val_gender_accuracy: 0.9596 - val_usage_accuracy: 0.9077 - val_article_accuracy: 0.8503 - lr: 0.0010
# Epoch 29/30
# 436/436 [==============================] - ETA: 0s - loss: 2.5258 - gender_loss: 0.1135 - usage_loss: 0.2196 - article_loss: 0.4408 - gender_accuracy: 0.9586 - usage_accuracy: 0.8992 - article_accuracy: 0.8283
# Epoch 29: val_loss did not improve from 2.27220
# 436/436 [==============================] - 422s 971ms/step - loss: 2.5258 - gender_loss: 0.1135 - usage_loss: 0.2196 - article_loss: 0.4408 - gender_accuracy: 0.9586 - usage_accuracy: 0.8992 - article_accuracy: 0.8283 - val_loss: 2.2783 - val_gender_loss: 0.1164 - val_usage_loss: 0.1720 - val_article_loss: 0.3411 - val_gender_accuracy: 0.9518 - val_usage_accuracy: 0.9240 - val_article_accuracy: 0.8667 - lr: 0.0010
# Epoch 30/30
# 436/436 [==============================] - ETA: 0s - loss: 2.4727 - gender_loss: 0.1082 - usage_loss: 0.2262 - article_loss: 0.4233 - gender_accuracy: 0.9596 - usage_accuracy: 0.8944 - article_accuracy: 0.8292
# Epoch 30: val_loss did not improve from 2.27220
# 436/436 [==============================] - 422s 971ms/step - loss: 2.4727 - gender_loss: 0.1082 - usage_loss: 0.2262 - article_loss: 0.4233 - gender_accuracy: 0.9596 - usage_accuracy: 0.8944 - article_accuracy: 0.8292 - val_loss: 3.2730 - val_gender_loss: 0.3354 - val_usage_loss: 0.2582 - val_article_loss: 0.5792 - val_gender_accuracy: 0.8965 - val_usage_accuracy: 0.8641 - val_article_accuracy: 0.7721 - lr: 0.0010
#
# --- Tahap 2: Fine Tuning ---
# Epoch 1/70
# 436/436 [==============================] - ETA: 0s - loss: 2.2567 - gender_loss: 0.0885 - usage_loss: 0.1990 - article_loss: 0.3644 - gender_accuracy: 0.9695 - usage_accuracy: 0.9095 - article_accuracy: 0.8526
# Epoch 1: val_loss improved from 2.27220 to 2.06436, saving model to best_robust_model.h5
# 436/436 [==============================] - 417s 959ms/step - loss: 2.2567 - gender_loss: 0.0885 - usage_loss: 0.1990 - article_loss: 0.3644 - gender_accuracy: 0.9695 - usage_accuracy: 0.9095 - article_accuracy: 0.8526 - val_loss: 2.0644 - val_gender_loss: 0.0877 - val_usage_loss: 0.1701 - val_article_loss: 0.3011 - val_gender_accuracy: 0.9622 - val_usage_accuracy: 0.9186 - val_article_accuracy: 0.8698 - lr: 1.0000e-04
# Epoch 2/70
# 436/436 [==============================] - ETA: 0s - loss: 2.0856 - gender_loss: 0.0744 - usage_loss: 0.1886 - article_loss: 0.3322 - gender_accuracy: 0.9745 - usage_accuracy: 0.9124 - article_accuracy: 0.8661
# Epoch 2: val_loss improved from 2.06436 to 2.02527, saving model to best_robust_model.h5
# 436/436 [==============================] - 453s 1s/step - loss: 2.0856 - gender_loss: 0.0744 - usage_loss: 0.1886 - article_loss: 0.3322 - gender_accuracy: 0.9745 - usage_accuracy: 0.9124 - article_accuracy: 0.8661 - val_loss: 2.0253 - val_gender_loss: 0.0953 - val_usage_loss: 0.1750 - val_article_loss: 0.3042 - val_gender_accuracy: 0.9613 - val_usage_accuracy: 0.9149 - val_article_accuracy: 0.8724 - lr: 1.0000e-04
# Epoch 3/70
# 436/436 [==============================] - ETA: 0s - loss: 1.9906 - gender_loss: 0.0711 - usage_loss: 0.1845 - article_loss: 0.3213 - gender_accuracy: 0.9756 - usage_accuracy: 0.9147 - article_accuracy: 0.8702
# Epoch 3: val_loss improved from 2.02527 to 1.93783, saving model to best_robust_model.h5
# 436/436 [==============================] - 479s 1s/step - loss: 1.9906 - gender_loss: 0.0711 - usage_loss: 0.1845 - article_loss: 0.3213 - gender_accuracy: 0.9756 - usage_accuracy: 0.9147 - article_accuracy: 0.8702 - val_loss: 1.9378 - val_gender_loss: 0.0928 - val_usage_loss: 0.1642 - val_article_loss: 0.2976 - val_gender_accuracy: 0.9627 - val_usage_accuracy: 0.9220 - val_article_accuracy: 0.8784 - lr: 1.0000e-04
# Epoch 4/70
# 436/436 [==============================] - ETA: 0s - loss: 1.9469 - gender_loss: 0.0777 - usage_loss: 0.1787 - article_loss: 0.3227 - gender_accuracy: 0.9735 - usage_accuracy: 0.9183 - article_accuracy: 0.8716
# Epoch 4: val_loss improved from 1.93783 to 1.79988, saving model to best_robust_model.h5
# 436/436 [==============================] - 490s 1s/step - loss: 1.9469 - gender_loss: 0.0777 - usage_loss: 0.1787 - article_loss: 0.3227 - gender_accuracy: 0.9735 - usage_accuracy: 0.9183 - article_accuracy: 0.8716 - val_loss: 1.7999 - val_gender_loss: 0.0681 - val_usage_loss: 0.1684 - val_article_loss: 0.2763 - val_gender_accuracy: 0.9708 - val_usage_accuracy: 0.9114 - val_article_accuracy: 0.8736 - lr: 1.0000e-04
# Epoch 5/70
# 436/436 [==============================] - ETA: 0s - loss: 1.8413 - gender_loss: 0.0665 - usage_loss: 0.1745 - article_loss: 0.3072 - gender_accuracy: 0.9776 - usage_accuracy: 0.9201 - article_accuracy: 0.8761
# Epoch 5: val_loss improved from 1.79988 to 1.74629, saving model to best_robust_model.h5
# 436/436 [==============================] - 496s 1s/step - loss: 1.8413 - gender_loss: 0.0665 - usage_loss: 0.1745 - article_loss: 0.3072 - gender_accuracy: 0.9776 - usage_accuracy: 0.9201 - article_accuracy: 0.8761 - val_loss: 1.7463 - val_gender_loss: 0.0715 - val_usage_loss: 0.1646 - val_article_loss: 0.2712 - val_gender_accuracy: 0.9705 - val_usage_accuracy: 0.9171 - val_article_accuracy: 0.8779 - lr: 1.0000e-04
# Epoch 6/70
# 436/436 [==============================] - ETA: 0s - loss: 1.7468 - gender_loss: 0.0606 - usage_loss: 0.1719 - article_loss: 0.2894 - gender_accuracy: 0.9785 - usage_accuracy: 0.9229 - article_accuracy: 0.8826
# Epoch 6: val_loss improved from 1.74629 to 1.65795, saving model to best_robust_model.h5
# 436/436 [==============================] - 470s 1s/step - loss: 1.7468 - gender_loss: 0.0606 - usage_loss: 0.1719 - article_loss: 0.2894 - gender_accuracy: 0.9785 - usage_accuracy: 0.9229 - article_accuracy: 0.8826 - val_loss: 1.6579 - val_gender_loss: 0.0651 - val_usage_loss: 0.1615 - val_article_loss: 0.2557 - val_gender_accuracy: 0.9739 - val_usage_accuracy: 0.9197 - val_article_accuracy: 0.8888 - lr: 1.0000e-04
# Epoch 7/70
# 436/436 [==============================] - ETA: 0s - loss: 1.7040 - gender_loss: 0.0634 - usage_loss: 0.1683 - article_loss: 0.2863 - gender_accuracy: 0.9775 - usage_accuracy: 0.9218 - article_accuracy: 0.8825
# Epoch 7: val_loss improved from 1.65795 to 1.56469, saving model to best_robust_model.h5
# 436/436 [==============================] - 459s 1s/step - loss: 1.7040 - gender_loss: 0.0634 - usage_loss: 0.1683 - article_loss: 0.2863 - gender_accuracy: 0.9775 - usage_accuracy: 0.9218 - article_accuracy: 0.8825 - val_loss: 1.5647 - val_gender_loss: 0.0542 - val_usage_loss: 0.1537 - val_article_loss: 0.2417 - val_gender_accuracy: 0.9782 - val_usage_accuracy: 0.9246 - val_article_accuracy: 0.8956 - lr: 1.0000e-04
# Epoch 8/70
# 436/436 [==============================] - ETA: 0s - loss: 1.6811 - gender_loss: 0.0603 - usage_loss: 0.1702 - article_loss: 0.2935 - gender_accuracy: 0.9781 - usage_accuracy: 0.9237 - article_accuracy: 0.8841
# Epoch 8: val_loss did not improve from 1.56469
# 436/436 [==============================] - 453s 1s/step - loss: 1.6811 - gender_loss: 0.0603 - usage_loss: 0.1702 - article_loss: 0.2935 - gender_accuracy: 0.9781 - usage_accuracy: 0.9237 - article_accuracy: 0.8841 - val_loss: 1.5715 - val_gender_loss: 0.0567 - val_usage_loss: 0.1615 - val_article_loss: 0.2543 - val_gender_accuracy: 0.9771 - val_usage_accuracy: 0.9169 - val_article_accuracy: 0.8827 - lr: 1.0000e-04
# Epoch 9/70
# 436/436 [==============================] - ETA: 0s - loss: 1.6060 - gender_loss: 0.0543 - usage_loss: 0.1659 - article_loss: 0.2792 - gender_accuracy: 0.9819 - usage_accuracy: 0.9256 - article_accuracy: 0.8884
# Epoch 9: val_loss improved from 1.56469 to 1.53852, saving model to best_robust_model.h5
# 436/436 [==============================] - 451s 1s/step - loss: 1.6060 - gender_loss: 0.0543 - usage_loss: 0.1659 - article_loss: 0.2792 - gender_accuracy: 0.9819 - usage_accuracy: 0.9256 - article_accuracy: 0.8884 - val_loss: 1.5385 - val_gender_loss: 0.0680 - val_usage_loss: 0.1498 - val_article_loss: 0.2474 - val_gender_accuracy: 0.9708 - val_usage_accuracy: 0.9329 - val_article_accuracy: 0.8971 - lr: 1.0000e-04
# Epoch 10/70
# 436/436 [==============================] - ETA: 0s - loss: 1.5895 - gender_loss: 0.0598 - usage_loss: 0.1682 - article_loss: 0.2785 - gender_accuracy: 0.9787 - usage_accuracy: 0.9231 - article_accuracy: 0.8889
# Epoch 10: val_loss improved from 1.53852 to 1.50711, saving model to best_robust_model.h5
# 436/436 [==============================] - 448s 1s/step - loss: 1.5895 - gender_loss: 0.0598 - usage_loss: 0.1682 - article_loss: 0.2785 - gender_accuracy: 0.9787 - usage_accuracy: 0.9231 - article_accuracy: 0.8889 - val_loss: 1.5071 - val_gender_loss: 0.0618 - val_usage_loss: 0.1536 - val_article_loss: 0.2491 - val_gender_accuracy: 0.9745 - val_usage_accuracy: 0.9249 - val_article_accuracy: 0.8913 - lr: 1.0000e-04
# Epoch 11/70
# 436/436 [==============================] - ETA: 0s - loss: 1.5529 - gender_loss: 0.0564 - usage_loss: 0.1668 - article_loss: 0.2769 - gender_accuracy: 0.9805 - usage_accuracy: 0.9257 - article_accuracy: 0.8891
# Epoch 11: val_loss improved from 1.50711 to 1.40992, saving model to best_robust_model.h5
# 436/436 [==============================] - 448s 1s/step - loss: 1.5529 - gender_loss: 0.0564 - usage_loss: 0.1668 - article_loss: 0.2769 - gender_accuracy: 0.9805 - usage_accuracy: 0.9257 - article_accuracy: 0.8891 - val_loss: 1.4099 - val_gender_loss: 0.0533 - val_usage_loss: 0.1420 - val_article_loss: 0.2270 - val_gender_accuracy: 0.9791 - val_usage_accuracy: 0.9355 - val_article_accuracy: 0.9060 - lr: 1.0000e-04
# Epoch 12/70
# 436/436 [==============================] - ETA: 0s - loss: 1.5294 - gender_loss: 0.0583 - usage_loss: 0.1652 - article_loss: 0.2758 - gender_accuracy: 0.9804 - usage_accuracy: 0.9268 - article_accuracy: 0.8903
# Epoch 12: val_loss did not improve from 1.40992
# 436/436 [==============================] - 449s 1s/step - loss: 1.5294 - gender_loss: 0.0583 - usage_loss: 0.1652 - article_loss: 0.2758 - gender_accuracy: 0.9804 - usage_accuracy: 0.9268 - article_accuracy: 0.8903 - val_loss: 1.4403 - val_gender_loss: 0.0592 - val_usage_loss: 0.1480 - val_article_loss: 0.2445 - val_gender_accuracy: 0.9762 - val_usage_accuracy: 0.9329 - val_article_accuracy: 0.8951 - lr: 1.0000e-04
# Epoch 13/70
# 436/436 [==============================] - ETA: 0s - loss: 1.4688 - gender_loss: 0.0518 - usage_loss: 0.1607 - article_loss: 0.2652 - gender_accuracy: 0.9834 - usage_accuracy: 0.9287 - article_accuracy: 0.8946
# Epoch 13: val_loss improved from 1.40992 to 1.34712, saving model to best_robust_model.h5
# 436/436 [==============================] - 449s 1s/step - loss: 1.4688 - gender_loss: 0.0518 - usage_loss: 0.1607 - article_loss: 0.2652 - gender_accuracy: 0.9834 - usage_accuracy: 0.9287 - article_accuracy: 0.8946 - val_loss: 1.3471 - val_gender_loss: 0.0517 - val_usage_loss: 0.1397 - val_article_loss: 0.2205 - val_gender_accuracy: 0.9819 - val_usage_accuracy: 0.9352 - val_article_accuracy: 0.9080 - lr: 1.0000e-04
# Epoch 14/70
# 436/436 [==============================] - ETA: 0s - loss: 1.4570 - gender_loss: 0.0547 - usage_loss: 0.1585 - article_loss: 0.2680 - gender_accuracy: 0.9809 - usage_accuracy: 0.9301 - article_accuracy: 0.8940
# Epoch 14: val_loss improved from 1.34712 to 1.33634, saving model to best_robust_model.h5
# 436/436 [==============================] - 448s 1s/step - loss: 1.4570 - gender_loss: 0.0547 - usage_loss: 0.1585 - article_loss: 0.2680 - gender_accuracy: 0.9809 - usage_accuracy: 0.9301 - article_accuracy: 0.8940 - val_loss: 1.3363 - val_gender_loss: 0.0501 - val_usage_loss: 0.1402 - val_article_loss: 0.2261 - val_gender_accuracy: 0.9791 - val_usage_accuracy: 0.9358 - val_article_accuracy: 0.9071 - lr: 1.0000e-04
# Epoch 15/70
# 436/436 [==============================] - ETA: 0s - loss: 1.4203 - gender_loss: 0.0515 - usage_loss: 0.1572 - article_loss: 0.2627 - gender_accuracy: 0.9824 - usage_accuracy: 0.9282 - article_accuracy: 0.8968
# Epoch 15: val_loss did not improve from 1.33634
# 436/436 [==============================] - 438s 1s/step - loss: 1.4203 - gender_loss: 0.0515 - usage_loss: 0.1572 - article_loss: 0.2627 - gender_accuracy: 0.9824 - usage_accuracy: 0.9282 - article_accuracy: 0.8968 - val_loss: 1.4590 - val_gender_loss: 0.0547 - val_usage_loss: 0.1830 - val_article_loss: 0.2705 - val_gender_accuracy: 0.9774 - val_usage_accuracy: 0.9106 - val_article_accuracy: 0.8787 - lr: 1.0000e-04
# Epoch 16/70
# 436/436 [==============================] - ETA: 0s - loss: 1.4057 - gender_loss: 0.0532 - usage_loss: 0.1564 - article_loss: 0.2628 - gender_accuracy: 0.9826 - usage_accuracy: 0.9302 - article_accuracy: 0.8968
# Epoch 16: val_loss did not improve from 1.33634
# 436/436 [==============================] - 432s 993ms/step - loss: 1.4057 - gender_loss: 0.0532 - usage_loss: 0.1564 - article_loss: 0.2628 - gender_accuracy: 0.9826 - usage_accuracy: 0.9302 - article_accuracy: 0.8968 - val_loss: 1.3786 - val_gender_loss: 0.0699 - val_usage_loss: 0.1443 - val_article_loss: 0.2430 - val_gender_accuracy: 0.9733 - val_usage_accuracy: 0.9346 - val_article_accuracy: 0.8982 - lr: 1.0000e-04
# Epoch 17/70
# 436/436 [==============================] - ETA: 0s - loss: 1.3843 - gender_loss: 0.0521 - usage_loss: 0.1609 - article_loss: 0.2595 - gender_accuracy: 0.9819 - usage_accuracy: 0.9284 - article_accuracy: 0.8984
# Epoch 17: val_loss improved from 1.33634 to 1.27309, saving model to best_robust_model.h5
# 436/436 [==============================] - 433s 994ms/step - loss: 1.3843 - gender_loss: 0.0521 - usage_loss: 0.1609 - article_loss: 0.2595 - gender_accuracy: 0.9819 - usage_accuracy: 0.9284 - article_accuracy: 0.8984 - val_loss: 1.2731 - val_gender_loss: 0.0562 - val_usage_loss: 0.1312 - val_article_loss: 0.2186 - val_gender_accuracy: 0.9785 - val_usage_accuracy: 0.9415 - val_article_accuracy: 0.9131 - lr: 1.0000e-04
# Epoch 18/70
# 436/436 [==============================] - ETA: 0s - loss: 1.3346 - gender_loss: 0.0446 - usage_loss: 0.1586 - article_loss: 0.2512 - gender_accuracy: 0.9859 - usage_accuracy: 0.9294 - article_accuracy: 0.8996
# Epoch 18: val_loss did not improve from 1.27309
# 436/436 [==============================] - 430s 987ms/step - loss: 1.3346 - gender_loss: 0.0446 - usage_loss: 0.1586 - article_loss: 0.2512 - gender_accuracy: 0.9859 - usage_accuracy: 0.9294 - article_accuracy: 0.8996 - val_loss: 1.2899 - val_gender_loss: 0.0511 - val_usage_loss: 0.1472 - val_article_loss: 0.2319 - val_gender_accuracy: 0.9808 - val_usage_accuracy: 0.9292 - val_article_accuracy: 0.9014 - lr: 1.0000e-04
# Epoch 19/70
# 436/436 [==============================] - ETA: 0s - loss: 1.3483 - gender_loss: 0.0541 - usage_loss: 0.1540 - article_loss: 0.2579 - gender_accuracy: 0.9824 - usage_accuracy: 0.9326 - article_accuracy: 0.8993
# Epoch 19: val_loss improved from 1.27309 to 1.22543, saving model to best_robust_model.h5
# 436/436 [==============================] - 425s 977ms/step - loss: 1.3483 - gender_loss: 0.0541 - usage_loss: 0.1540 - article_loss: 0.2579 - gender_accuracy: 0.9824 - usage_accuracy: 0.9326 - article_accuracy: 0.8993 - val_loss: 1.2254 - val_gender_loss: 0.0492 - val_usage_loss: 0.1333 - val_article_loss: 0.2151 - val_gender_accuracy: 0.9814 - val_usage_accuracy: 0.9407 - val_article_accuracy: 0.9151 - lr: 1.0000e-04
# Epoch 20/70
# 436/436 [==============================] - ETA: 0s - loss: 1.2894 - gender_loss: 0.0455 - usage_loss: 0.1539 - article_loss: 0.2438 - gender_accuracy: 0.9849 - usage_accuracy: 0.9332 - article_accuracy: 0.9037
# Epoch 20: val_loss did not improve from 1.22543
# 436/436 [==============================] - 425s 978ms/step - loss: 1.2894 - gender_loss: 0.0455 - usage_loss: 0.1539 - article_loss: 0.2438 - gender_accuracy: 0.9849 - usage_accuracy: 0.9332 - article_accuracy: 0.9037 - val_loss: 1.2923 - val_gender_loss: 0.0450 - val_usage_loss: 0.1637 - val_article_loss: 0.2440 - val_gender_accuracy: 0.9831 - val_usage_accuracy: 0.9243 - val_article_accuracy: 0.8991 - lr: 1.0000e-04
# Epoch 21/70
# 436/436 [==============================] - ETA: 0s - loss: 1.2891 - gender_loss: 0.0492 - usage_loss: 0.1482 - article_loss: 0.2490 - gender_accuracy: 0.9839 - usage_accuracy: 0.9349 - article_accuracy: 0.9008
# Epoch 21: val_loss did not improve from 1.22543
# 436/436 [==============================] - 424s 974ms/step - loss: 1.2891 - gender_loss: 0.0492 - usage_loss: 0.1482 - article_loss: 0.2490 - gender_accuracy: 0.9839 - usage_accuracy: 0.9349 - article_accuracy: 0.9008 - val_loss: 1.2342 - val_gender_loss: 0.0510 - val_usage_loss: 0.1467 - val_article_loss: 0.2237 - val_gender_accuracy: 0.9817 - val_usage_accuracy: 0.9349 - val_article_accuracy: 0.9103 - lr: 1.0000e-04
# Epoch 22/70
# 436/436 [==============================] - ETA: 0s - loss: 1.2681 - gender_loss: 0.0500 - usage_loss: 0.1523 - article_loss: 0.2418 - gender_accuracy: 0.9832 - usage_accuracy: 0.9315 - article_accuracy: 0.9036
# Epoch 22: val_loss did not improve from 1.22543
# 436/436 [==============================] - 423s 972ms/step - loss: 1.2681 - gender_loss: 0.0500 - usage_loss: 0.1523 - article_loss: 0.2418 - gender_accuracy: 0.9832 - usage_accuracy: 0.9315 - article_accuracy: 0.9036 - val_loss: 1.2589 - val_gender_loss: 0.0597 - val_usage_loss: 0.1495 - val_article_loss: 0.2317 - val_gender_accuracy: 0.9776 - val_usage_accuracy: 0.9312 - val_article_accuracy: 0.9045 - lr: 1.0000e-04
# Epoch 23/70
# 436/436 [==============================] - ETA: 0s - loss: 1.2500 - gender_loss: 0.0500 - usage_loss: 0.1452 - article_loss: 0.2419 - gender_accuracy: 0.9842 - usage_accuracy: 0.9372 - article_accuracy: 0.9060
# Epoch 23: val_loss did not improve from 1.22543
# 436/436 [==============================] - 419s 962ms/step - loss: 1.2500 - gender_loss: 0.0500 - usage_loss: 0.1452 - article_loss: 0.2419 - gender_accuracy: 0.9842 - usage_accuracy: 0.9372 - article_accuracy: 0.9060 - val_loss: 1.3291 - val_gender_loss: 0.0578 - val_usage_loss: 0.1748 - val_article_loss: 0.2615 - val_gender_accuracy: 0.9785 - val_usage_accuracy: 0.9203 - val_article_accuracy: 0.8919 - lr: 1.0000e-04
# Epoch 24/70
# 436/436 [==============================] - ETA: 0s - loss: 1.2538 - gender_loss: 0.0491 - usage_loss: 0.1553 - article_loss: 0.2450 - gender_accuracy: 0.9826 - usage_accuracy: 0.9317 - article_accuracy: 0.9027
# Epoch 24: val_loss did not improve from 1.22543
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 436/436 [==============================] - 416s 956ms/step - loss: 1.2538 - gender_loss: 0.0491 - usage_loss: 0.1553 - article_loss: 0.2450 - gender_accuracy: 0.9826 - usage_accuracy: 0.9317 - article_accuracy: 0.9027 - val_loss: 1.2983 - val_gender_loss: 0.0506 - val_usage_loss: 0.1741 - val_article_loss: 0.2588 - val_gender_accuracy: 0.9799 - val_usage_accuracy: 0.9223 - val_article_accuracy: 0.8954 - lr: 1.0000e-04
# Epoch 25/70
# 436/436 [==============================] - ETA: 0s - loss: 1.1967 - gender_loss: 0.0444 - usage_loss: 0.1425 - article_loss: 0.2316 - gender_accuracy: 0.9850 - usage_accuracy: 0.9392 - article_accuracy: 0.9094
# Epoch 25: val_loss did not improve from 1.22543
# 436/436 [==============================] - 415s 954ms/step - loss: 1.1967 - gender_loss: 0.0444 - usage_loss: 0.1425 - article_loss: 0.2316 - gender_accuracy: 0.9850 - usage_accuracy: 0.9392 - article_accuracy: 0.9094 - val_loss: 1.2566 - val_gender_loss: 0.0461 - val_usage_loss: 0.1654 - val_article_loss: 0.2502 - val_gender_accuracy: 0.9799 - val_usage_accuracy: 0.9260 - val_article_accuracy: 0.8948 - lr: 5.0000e-05
# Epoch 26/70
# 436/436 [==============================] - ETA: 0s - loss: 1.1662 - gender_loss: 0.0411 - usage_loss: 0.1398 - article_loss: 0.2245 - gender_accuracy: 0.9862 - usage_accuracy: 0.9377 - article_accuracy: 0.9122
# Epoch 26: val_loss improved from 1.22543 to 1.19077, saving model to best_robust_model.h5
# 436/436 [==============================] - 425s 975ms/step - loss: 1.1662 - gender_loss: 0.0411 - usage_loss: 0.1398 - article_loss: 0.2245 - gender_accuracy: 0.9862 - usage_accuracy: 0.9377 - article_accuracy: 0.9122 - val_loss: 1.1908 - val_gender_loss: 0.0496 - val_usage_loss: 0.1456 - val_article_loss: 0.2272 - val_gender_accuracy: 0.9817 - val_usage_accuracy: 0.9358 - val_article_accuracy: 0.9080 - lr: 5.0000e-05
# Epoch 27/70
# 436/436 [==============================] - ETA: 0s - loss: 1.1572 - gender_loss: 0.0383 - usage_loss: 0.1410 - article_loss: 0.2257 - gender_accuracy: 0.9881 - usage_accuracy: 0.9405 - article_accuracy: 0.9130
# Epoch 27: val_loss improved from 1.19077 to 1.17676, saving model to best_robust_model.h5
# 436/436 [==============================] - 440s 1s/step - loss: 1.1572 - gender_loss: 0.0383 - usage_loss: 0.1410 - article_loss: 0.2257 - gender_accuracy: 0.9881 - usage_accuracy: 0.9405 - article_accuracy: 0.9130 - val_loss: 1.1768 - val_gender_loss: 0.0441 - val_usage_loss: 0.1488 - val_article_loss: 0.2274 - val_gender_accuracy: 0.9817 - val_usage_accuracy: 0.9369 - val_article_accuracy: 0.9094 - lr: 5.0000e-05
# Epoch 28/70
# 436/436 [==============================] - ETA: 0s - loss: 1.1424 - gender_loss: 0.0398 - usage_loss: 0.1413 - article_loss: 0.2198 - gender_accuracy: 0.9880 - usage_accuracy: 0.9393 - article_accuracy: 0.9127
# Epoch 28: val_loss did not improve from 1.17676
# 436/436 [==============================] - 432s 992ms/step - loss: 1.1424 - gender_loss: 0.0398 - usage_loss: 0.1413 - article_loss: 0.2198 - gender_accuracy: 0.9880 - usage_accuracy: 0.9393 - article_accuracy: 0.9127 - val_loss: 1.2431 - val_gender_loss: 0.0492 - val_usage_loss: 0.1666 - val_article_loss: 0.2498 - val_gender_accuracy: 0.9802 - val_usage_accuracy: 0.9283 - val_article_accuracy: 0.9011 - lr: 5.0000e-05
# Epoch 29/70
# 436/436 [==============================] - ETA: 0s - loss: 1.1522 - gender_loss: 0.0383 - usage_loss: 0.1440 - article_loss: 0.2281 - gender_accuracy: 0.9872 - usage_accuracy: 0.9373 - article_accuracy: 0.9113
# Epoch 29: val_loss improved from 1.17676 to 1.14571, saving model to best_robust_model.h5
# 436/436 [==============================] - 440s 1s/step - loss: 1.1522 - gender_loss: 0.0383 - usage_loss: 0.1440 - article_loss: 0.2281 - gender_accuracy: 0.9872 - usage_accuracy: 0.9373 - article_accuracy: 0.9113 - val_loss: 1.1457 - val_gender_loss: 0.0450 - val_usage_loss: 0.1446 - val_article_loss: 0.2193 - val_gender_accuracy: 0.9825 - val_usage_accuracy: 0.9369 - val_article_accuracy: 0.9114 - lr: 5.0000e-05
# Epoch 30/70
# 436/436 [==============================] - ETA: 0s - loss: 1.1538 - gender_loss: 0.0424 - usage_loss: 0.1404 - article_loss: 0.2296 - gender_accuracy: 0.9859 - usage_accuracy: 0.9376 - article_accuracy: 0.9078
# Epoch 30: val_loss did not improve from 1.14571
# 436/436 [==============================] - 448s 1s/step - loss: 1.1538 - gender_loss: 0.0424 - usage_loss: 0.1404 - article_loss: 0.2296 - gender_accuracy: 0.9859 - usage_accuracy: 0.9376 - article_accuracy: 0.9078 - val_loss: 1.1465 - val_gender_loss: 0.0367 - val_usage_loss: 0.1595 - val_article_loss: 0.2235 - val_gender_accuracy: 0.9860 - val_usage_accuracy: 0.9280 - val_article_accuracy: 0.9088 - lr: 5.0000e-05
# Epoch 31/70
# 436/436 [==============================] - ETA: 0s - loss: 1.1116 - gender_loss: 0.0403 - usage_loss: 0.1333 - article_loss: 0.2171 - gender_accuracy: 0.9870 - usage_accuracy: 0.9422 - article_accuracy: 0.9150
# Epoch 31: val_loss improved from 1.14571 to 1.12544, saving model to best_robust_model.h5
# 436/436 [==============================] - 436s 1s/step - loss: 1.1116 - gender_loss: 0.0403 - usage_loss: 0.1333 - article_loss: 0.2171 - gender_accuracy: 0.9870 - usage_accuracy: 0.9422 - article_accuracy: 0.9150 - val_loss: 1.1254 - val_gender_loss: 0.0458 - val_usage_loss: 0.1385 - val_article_loss: 0.2173 - val_gender_accuracy: 0.9825 - val_usage_accuracy: 0.9398 - val_article_accuracy: 0.9160 - lr: 5.0000e-05
# Epoch 32/70
# 436/436 [==============================] - ETA: 0s - loss: 1.1168 - gender_loss: 0.0385 - usage_loss: 0.1408 - article_loss: 0.2206 - gender_accuracy: 0.9877 - usage_accuracy: 0.9382 - article_accuracy: 0.9115
# Epoch 32: val_loss did not improve from 1.12544
# 436/436 [==============================] - 430s 987ms/step - loss: 1.1168 - gender_loss: 0.0385 - usage_loss: 0.1408 - article_loss: 0.2206 - gender_accuracy: 0.9877 - usage_accuracy: 0.9382 - article_accuracy: 0.9115 - val_loss: 1.1910 - val_gender_loss: 0.0425 - val_usage_loss: 0.1675 - val_article_loss: 0.2416 - val_gender_accuracy: 0.9834 - val_usage_accuracy: 0.9257 - val_article_accuracy: 0.9028 - lr: 5.0000e-05
# Epoch 33/70
# 436/436 [==============================] - ETA: 0s - loss: 1.0918 - gender_loss: 0.0363 - usage_loss: 0.1346 - article_loss: 0.2160 - gender_accuracy: 0.9882 - usage_accuracy: 0.9410 - article_accuracy: 0.9158
# Epoch 33: val_loss improved from 1.12544 to 1.10544, saving model to best_robust_model.h5
# 436/436 [==============================] - 426s 979ms/step - loss: 1.0918 - gender_loss: 0.0363 - usage_loss: 0.1346 - article_loss: 0.2160 - gender_accuracy: 0.9882 - usage_accuracy: 0.9410 - article_accuracy: 0.9158 - val_loss: 1.1054 - val_gender_loss: 0.0404 - val_usage_loss: 0.1391 - val_article_loss: 0.2177 - val_gender_accuracy: 0.9854 - val_usage_accuracy: 0.9409 - val_article_accuracy: 0.9157 - lr: 5.0000e-05
# Epoch 34/70
# 436/436 [==============================] - ETA: 0s - loss: 1.0873 - gender_loss: 0.0376 - usage_loss: 0.1365 - article_loss: 0.2141 - gender_accuracy: 0.9881 - usage_accuracy: 0.9411 - article_accuracy: 0.9147
# Epoch 34: val_loss improved from 1.10544 to 1.09955, saving model to best_robust_model.h5
# 436/436 [==============================] - 429s 987ms/step - loss: 1.0873 - gender_loss: 0.0376 - usage_loss: 0.1365 - article_loss: 0.2141 - gender_accuracy: 0.9881 - usage_accuracy: 0.9411 - article_accuracy: 0.9147 - val_loss: 1.0995 - val_gender_loss: 0.0474 - val_usage_loss: 0.1362 - val_article_loss: 0.2118 - val_gender_accuracy: 0.9825 - val_usage_accuracy: 0.9381 - val_article_accuracy: 0.9143 - lr: 5.0000e-05
# Epoch 35/70
# 436/436 [==============================] - ETA: 0s - loss: 1.0792 - gender_loss: 0.0394 - usage_loss: 0.1342 - article_loss: 0.2119 - gender_accuracy: 0.9873 - usage_accuracy: 0.9436 - article_accuracy: 0.9178
# Epoch 35: val_loss did not improve from 1.09955
# 436/436 [==============================] - 430s 988ms/step - loss: 1.0792 - gender_loss: 0.0394 - usage_loss: 0.1342 - article_loss: 0.2119 - gender_accuracy: 0.9873 - usage_accuracy: 0.9436 - article_accuracy: 0.9178 - val_loss: 1.1093 - val_gender_loss: 0.0378 - val_usage_loss: 0.1532 - val_article_loss: 0.2205 - val_gender_accuracy: 0.9880 - val_usage_accuracy: 0.9318 - val_article_accuracy: 0.9154 - lr: 5.0000e-05
# Epoch 36/70
# 436/436 [==============================] - ETA: 0s - loss: 1.0711 - gender_loss: 0.0370 - usage_loss: 0.1379 - article_loss: 0.2111 - gender_accuracy: 0.9882 - usage_accuracy: 0.9413 - article_accuracy: 0.9188
# Epoch 36: val_loss did not improve from 1.09955
# 436/436 [==============================] - 427s 980ms/step - loss: 1.0711 - gender_loss: 0.0370 - usage_loss: 0.1379 - article_loss: 0.2111 - gender_accuracy: 0.9882 - usage_accuracy: 0.9413 - article_accuracy: 0.9188 - val_loss: 1.1229 - val_gender_loss: 0.0394 - val_usage_loss: 0.1500 - val_article_loss: 0.2298 - val_gender_accuracy: 0.9851 - val_usage_accuracy: 0.9326 - val_article_accuracy: 0.9120 - lr: 5.0000e-05
# Epoch 37/70
# 436/436 [==============================] - ETA: 0s - loss: 1.0643 - gender_loss: 0.0370 - usage_loss: 0.1378 - article_loss: 0.2101 - gender_accuracy: 0.9865 - usage_accuracy: 0.9404 - article_accuracy: 0.9153
# Epoch 37: val_loss improved from 1.09955 to 1.09734, saving model to best_robust_model.h5
# 436/436 [==============================] - 418s 960ms/step - loss: 1.0643 - gender_loss: 0.0370 - usage_loss: 0.1378 - article_loss: 0.2101 - gender_accuracy: 0.9865 - usage_accuracy: 0.9404 - article_accuracy: 0.9153 - val_loss: 1.0973 - val_gender_loss: 0.0363 - val_usage_loss: 0.1480 - val_article_loss: 0.2233 - val_gender_accuracy: 0.9877 - val_usage_accuracy: 0.9358 - val_article_accuracy: 0.9160 - lr: 5.0000e-05
# Epoch 38/70
# ...
# Epoch 49/70
# 436/436 [==============================] - ETA: 0s - loss: 0.9681 - gender_loss: 0.0345 - usage_loss: 0.1240 - article_loss: 0.1947 - gender_accuracy: 0.9892 - usage_accuracy: 0.9472 - article_accuracy: 0.9249
# Epoch 49: val_loss did not improve from 1.03660
# 436/436 [==============================] - 452s 1s/step - loss: 0.9681 - gender_loss: 0.0345 - usage_loss: 0.1240 - article_loss: 0.1947 - gender_accuracy: 0.9892 - usage_accuracy: 0.9472 - article_accuracy: 0.9249 - val_loss: 1.0600 - val_gender_loss: 0.0382 - val_usage_loss: 0.1460 - val_article_loss: 0.2266 - val_gender_accuracy: 0.9862 - val_usage_accuracy: 0.9355 - val_article_accuracy: 0.9146 - lr: 2.5000e-05
# Epoch 50/70
# 436/436 [==============================] - ETA: 0s - loss: 0.9730 - gender_loss: 0.0349 - usage_loss: 0.1296 - article_loss: 0.1951 - gender_accuracy: 0.9892 - usage_accuracy: 0.9457 - article_accuracy: 0.9245
# Epoch 50: val_loss improved from 1.03660 to 0.98747, saving model to best_robust_model.h5
# 436/436 [==============================] - 441s 1s/step - loss: 0.9730 - gender_loss: 0.0349 - usage_loss: 0.1296 - article_loss: 0.1951 - gender_accuracy: 0.9892 - usage_accuracy: 0.9457 - article_accuracy: 0.9245 - val_loss: 0.9875 - val_gender_loss: 0.0369 - val_usage_loss: 0.1289 - val_article_loss: 0.2012 - val_gender_accuracy: 0.9868 - val_usage_accuracy: 0.9438 - val_article_accuracy: 0.9223 - lr: 2.5000e-05
# Epoch 51/70
# 436/436 [==============================] - ETA: 0s - loss: 0.9654 - gender_loss: 0.0360 - usage_loss: 0.1238 - article_loss: 0.1942 - gender_accuracy: 0.9892 - usage_accuracy: 0.9470 - article_accuracy: 0.9248
# Epoch 51: val_loss improved from 0.98747 to 0.97913, saving model to best_robust_model.h5
# 436/436 [==============================] - 446s 1s/step - loss: 0.9654 - gender_loss: 0.0360 - usage_loss: 0.1238 - article_loss: 0.1942 - gender_accuracy: 0.9892 - usage_accuracy: 0.9470 - article_accuracy: 0.9248 - val_loss: 0.9791 - val_gender_loss: 0.0339 - val_usage_loss: 0.1298 - val_article_loss: 0.2008 - val_gender_accuracy: 0.9882 - val_usage_accuracy: 0.9432 - val_article_accuracy: 0.9243 - lr: 2.5000e-05
# Epoch 52/70
# 436/436 [==============================] - ETA: 0s - loss: 0.9543 - gender_loss: 0.0316 - usage_loss: 0.1269 - article_loss: 0.1928 - gender_accuracy: 0.9901 - usage_accuracy: 0.9451 - article_accuracy: 0.9254
# Epoch 52: val_loss did not improve from 0.97913
# 436/436 [==============================] - 449s 1s/step - loss: 0.9543 - gender_loss: 0.0316 - usage_loss: 0.1269 - article_loss: 0.1928 - gender_accuracy: 0.9901 - usage_accuracy: 0.9451 - article_accuracy: 0.9254 - val_loss: 1.0363 - val_gender_loss: 0.0367 - val_usage_loss: 0.1479 - val_article_loss: 0.2186 - val_gender_accuracy: 0.9854 - val_usage_accuracy: 0.9361 - val_article_accuracy: 0.9171 - lr: 2.5000e-05
# Epoch 53/70
# 436/436 [==============================] - ETA: 0s - loss: 0.9682 - gender_loss: 0.0353 - usage_loss: 0.1262 - article_loss: 0.1974 - gender_accuracy: 0.9897 - usage_accuracy: 0.9463 - article_accuracy: 0.9254
# Epoch 53: val_loss did not improve from 0.97913
# 436/436 [==============================] - 501s 1s/step - loss: 0.9682 - gender_loss: 0.0353 - usage_loss: 0.1262 - article_loss: 0.1974 - gender_accuracy: 0.9897 - usage_accuracy: 0.9463 - article_accuracy: 0.9254 - val_loss: 0.9988 - val_gender_loss: 0.0362 - val_usage_loss: 0.1360 - val_article_loss: 0.2075 - val_gender_accuracy: 0.9871 - val_usage_accuracy: 0.9407 - val_article_accuracy: 0.9212 - lr: 2.5000e-05
# Epoch 54/70
# 436/436 [==============================] - ETA: 0s - loss: 0.9366 - gender_loss: 0.0334 - usage_loss: 0.1228 - article_loss: 0.1862 - gender_accuracy: 0.9890 - usage_accuracy: 0.9476 - article_accuracy: 0.9280
# Epoch 54: val_loss improved from 0.97913 to 0.97871, saving model to best_robust_model.h5
# 436/436 [==============================] - 482s 1s/step - loss: 0.9366 - gender_loss: 0.0334 - usage_loss: 0.1228 - article_loss: 0.1862 - gender_accuracy: 0.9890 - usage_accuracy: 0.9476 - article_accuracy: 0.9280 - val_loss: 0.9787 - val_gender_loss: 0.0353 - val_usage_loss: 0.1304 - val_article_loss: 0.2021 - val_gender_accuracy: 0.9882 - val_usage_accuracy: 0.9432 - val_article_accuracy: 0.9257 - lr: 2.5000e-05
# Epoch 55/70
# 436/436 [==============================] - ETA: 0s - loss: 0.9398 - gender_loss: 0.0335 - usage_loss: 0.1238 - article_loss: 0.1883 - gender_accuracy: 0.9896 - usage_accuracy: 0.9482 - article_accuracy: 0.9294
# Epoch 55: val_loss did not improve from 0.97871
# 436/436 [==============================] - 450s 1s/step - loss: 0.9398 - gender_loss: 0.0335 - usage_loss: 0.1238 - article_loss: 0.1883 - gender_accuracy: 0.9896 - usage_accuracy: 0.9482 - article_accuracy: 0.9294 - val_loss: 0.9880 - val_gender_loss: 0.0346 - val_usage_loss: 0.1347 - val_article_loss: 0.2065 - val_gender_accuracy: 0.9880 - val_usage_accuracy: 0.9407 - val_article_accuracy: 0.9226 - lr: 2.5000e-05
# Epoch 56/70
# 436/436 [==============================] - ETA: 0s - loss: 0.9273 - gender_loss: 0.0286 - usage_loss: 0.1241 - article_loss: 0.1879 - gender_accuracy: 0.9905 - usage_accuracy: 0.9484 - article_accuracy: 0.9260
# Epoch 56: val_loss did not improve from 0.97871
# 436/436 [==============================] - 435s 999ms/step - loss: 0.9273 - gender_loss: 0.0286 - usage_loss: 0.1241 - article_loss: 0.1879 - gender_accuracy: 0.9905 - usage_accuracy: 0.9484 - article_accuracy: 0.9260 - val_loss: 0.9939 - val_gender_loss: 0.0348 - val_usage_loss: 0.1366 - val_article_loss: 0.2092 - val_gender_accuracy: 0.9871 - val_usage_accuracy: 0.9412 - val_article_accuracy: 0.9223 - lr: 2.5000e-05
# Epoch 57/70
# 436/436 [==============================] - ETA: 0s - loss: 0.9343 - gender_loss: 0.0315 - usage_loss: 0.1258 - article_loss: 0.1886 - gender_accuracy: 0.9899 - usage_accuracy: 0.9462 - article_accuracy: 0.9264
# Epoch 57: val_loss did not improve from 0.97871
# 436/436 [==============================] - 439s 1s/step - loss: 0.9343 - gender_loss: 0.0315 - usage_loss: 0.1258 - article_loss: 0.1886 - gender_accuracy: 0.9899 - usage_accuracy: 0.9462 - article_accuracy: 0.9264 - val_loss: 0.9966 - val_gender_loss: 0.0318 - val_usage_loss: 0.1420 - val_article_loss: 0.2119 - val_gender_accuracy: 0.9885 - val_usage_accuracy: 0.9398 - val_article_accuracy: 0.9226 - lr: 2.5000e-05
# Epoch 58/70
# 436/436 [==============================] - ETA: 0s - loss: 0.9391 - gender_loss: 0.0364 - usage_loss: 0.1241 - article_loss: 0.1880 - gender_accuracy: 0.9898 - usage_accuracy: 0.9481 - article_accuracy: 0.9287
# Epoch 58: val_loss did not improve from 0.97871
# 436/436 [==============================] - 434s 997ms/step - loss: 0.9391 - gender_loss: 0.0364 - usage_loss: 0.1241 - article_loss: 0.1880 - gender_accuracy: 0.9898 - usage_accuracy: 0.9481 - article_accuracy: 0.9287 - val_loss: 0.9830 - val_gender_loss: 0.0340 - val_usage_loss: 0.1352 - val_article_loss: 0.2073 - val_gender_accuracy: 0.9874 - val_usage_accuracy: 0.9418 - val_article_accuracy: 0.9237 - lr: 2.5000e-05
# Epoch 59/70
# 436/436 [==============================] - ETA: 0s - loss: 0.9151 - gender_loss: 0.0295 - usage_loss: 0.1256 - article_loss: 0.1831 - gender_accuracy: 0.9906 - usage_accuracy: 0.9459 - article_accuracy: 0.9261
# Epoch 59: val_loss did not improve from 0.97871
#
# Epoch 59: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 436/436 [==============================] - 433s 994ms/step - loss: 0.9151 - gender_loss: 0.0295 - usage_loss: 0.1256 - article_loss: 0.1831 - gender_accuracy: 0.9906 - usage_accuracy: 0.9459 - article_accuracy: 0.9261 - val_loss: 0.9897 - val_gender_loss: 0.0360 - val_usage_loss: 0.1344 - val_article_loss: 0.2100 - val_gender_accuracy: 0.9862 - val_usage_accuracy: 0.9438 - val_article_accuracy: 0.9232 - lr: 2.5000e-05
# Epoch 60/70
# 436/436 [==============================] - ETA: 0s - loss: 0.9242 - gender_loss: 0.0331 - usage_loss: 0.1215 - article_loss: 0.1868 - gender_accuracy: 0.9885 - usage_accuracy: 0.9493 - article_accuracy: 0.9276
# Epoch 60: val_loss improved from 0.97871 to 0.96224, saving model to best_robust_model.h5
# 436/436 [==============================] - 430s 989ms/step - loss: 0.9242 - gender_loss: 0.0331 - usage_loss: 0.1215 - article_loss: 0.1868 - gender_accuracy: 0.9885 - usage_accuracy: 0.9493 - article_accuracy: 0.9276 - val_loss: 0.9622 - val_gender_loss: 0.0356 - val_usage_loss: 0.1294 - val_article_loss: 0.1997 - val_gender_accuracy: 0.9877 - val_usage_accuracy: 0.9424 - val_article_accuracy: 0.9235 - lr: 1.2500e-05
# Epoch 61/70
# 436/436 [==============================] - ETA: 0s - loss: 0.9012 - gender_loss: 0.0283 - usage_loss: 0.1189 - article_loss: 0.1821 - gender_accuracy: 0.9902 - usage_accuracy: 0.9484 - article_accuracy: 0.9299
# Epoch 61: val_loss did not improve from 0.96224
# 436/436 [==============================] - 439s 1s/step - loss: 0.9012 - gender_loss: 0.0283 - usage_loss: 0.1189 - article_loss: 0.1821 - gender_accuracy: 0.9902 - usage_accuracy: 0.9484 - article_accuracy: 0.9299 - val_loss: 1.0047 - val_gender_loss: 0.0353 - val_usage_loss: 0.1416 - val_article_loss: 0.2158 - val_gender_accuracy: 0.9877 - val_usage_accuracy: 0.9389 - val_article_accuracy: 0.9209 - lr: 1.2500e-05
# Epoch 62/70
# 436/436 [==============================] - ETA: 0s - loss: 0.9450 - gender_loss: 0.0351 - usage_loss: 0.1253 - article_loss: 0.1945 - gender_accuracy: 0.9900 - usage_accuracy: 0.9482 - article_accuracy: 0.9251
# Epoch 62: val_loss did not improve from 0.96224
# 436/436 [==============================] - 435s 999ms/step - loss: 0.9450 - gender_loss: 0.0351 - usage_loss: 0.1253 - article_loss: 0.1945 - gender_accuracy: 0.9900 - usage_accuracy: 0.9482 - article_accuracy: 0.9251 - val_loss: 0.9764 - val_gender_loss: 0.0347 - val_usage_loss: 0.1366 - val_article_loss: 0.2052 - val_gender_accuracy: 0.9874 - val_usage_accuracy: 0.9409 - val_article_accuracy: 0.9237 - lr: 1.2500e-05
# Epoch 63/70
# 436/436 [==============================] - ETA: 0s - loss: 0.9046 - gender_loss: 0.0296 - usage_loss: 0.1213 - article_loss: 0.1823 - gender_accuracy: 0.9907 - usage_accuracy: 0.9489 - article_accuracy: 0.9272
# Epoch 63: val_loss did not improve from 0.96224
# 436/436 [==============================] - 435s 1s/step - loss: 0.9046 - gender_loss: 0.0296 - usage_loss: 0.1213 - article_loss: 0.1823 - gender_accuracy: 0.9907 - usage_accuracy: 0.9489 - article_accuracy: 0.9272 - val_loss: 1.0196 - val_gender_loss: 0.0343 - val_usage_loss: 0.1503 - val_article_loss: 0.2208 - val_gender_accuracy: 0.9871 - val_usage_accuracy: 0.9369 - val_article_accuracy: 0.9189 - lr: 1.2500e-05
# Epoch 64/70
# 436/436 [==============================] - ETA: 0s - loss: 0.9200 - gender_loss: 0.0353 - usage_loss: 0.1210 - article_loss: 0.1850 - gender_accuracy: 0.9892 - usage_accuracy: 0.9486 - article_accuracy: 0.9275
# Epoch 64: val_loss did not improve from 0.96224
# 436/436 [==============================] - 435s 1s/step - loss: 0.9200 - gender_loss: 0.0353 - usage_loss: 0.1210 - article_loss: 0.1850 - gender_accuracy: 0.9892 - usage_accuracy: 0.9486 - article_accuracy: 0.9275 - val_loss: 0.9702 - val_gender_loss: 0.0333 - val_usage_loss: 0.1371 - val_article_loss: 0.2043 - val_gender_accuracy: 0.9882 - val_usage_accuracy: 0.9412 - val_article_accuracy: 0.9235 - lr: 1.2500e-05
# Epoch 65/70
# 436/436 [==============================] - ETA: 0s - loss: 0.8888 - gender_loss: 0.0291 - usage_loss: 0.1172 - article_loss: 0.1781 - gender_accuracy: 0.9906 - usage_accuracy: 0.9530 - article_accuracy: 0.9322
# Epoch 65: val_loss did not improve from 0.96224
#
# Epoch 65: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 436/436 [==============================] - 434s 997ms/step - loss: 0.8888 - gender_loss: 0.0291 - usage_loss: 0.1172 - article_loss: 0.1781 - gender_accuracy: 0.9906 - usage_accuracy: 0.9530 - article_accuracy: 0.9322 - val_loss: 0.9833 - val_gender_loss: 0.0355 - val_usage_loss: 0.1392 - val_article_loss: 0.2081 - val_gender_accuracy: 0.9865 - val_usage_accuracy: 0.9418 - val_article_accuracy: 0.9237 - lr: 1.2500e-05
# Epoch 66/70
# 436/436 [==============================] - ETA: 0s - loss: 0.9190 - gender_loss: 0.0334 - usage_loss: 0.1232 - article_loss: 0.1862 - gender_accuracy: 0.9888 - usage_accuracy: 0.9473 - article_accuracy: 0.9267
# Epoch 66: val_loss did not improve from 0.96224
# 436/436 [==============================] - 434s 997ms/step - loss: 0.9190 - gender_loss: 0.0334 - usage_loss: 0.1232 - article_loss: 0.1862 - gender_accuracy: 0.9888 - usage_accuracy: 0.9473 - article_accuracy: 0.9267 - val_loss: 1.0283 - val_gender_loss: 0.0357 - val_usage_loss: 0.1508 - val_article_loss: 0.2249 - val_gender_accuracy: 0.9865 - val_usage_accuracy: 0.9384 - val_article_accuracy: 0.9183 - lr: 6.2500e-06
# Epoch 67/70
# 436/436 [==============================] - ETA: 0s - loss: 0.8879 - gender_loss: 0.0299 - usage_loss: 0.1154 - article_loss: 0.1783 - gender_accuracy: 0.9906 - usage_accuracy: 0.9497 - article_accuracy: 0.9319
# Epoch 67: val_loss did not improve from 0.96224
# 436/436 [==============================] - 432s 993ms/step - loss: 0.8879 - gender_loss: 0.0299 - usage_loss: 0.1154 - article_loss: 0.1783 - gender_accuracy: 0.9906 - usage_accuracy: 0.9497 - article_accuracy: 0.9319 - val_loss: 1.0157 - val_gender_loss: 0.0359 - val_usage_loss: 0.1456 - val_article_loss: 0.2213 - val_gender_accuracy: 0.9880 - val_usage_accuracy: 0.9384 - val_article_accuracy: 0.9209 - lr: 6.2500e-06
# Epoch 68/70
# 436/436 [==============================] - ETA: 0s - loss: 0.8765 - gender_loss: 0.0277 - usage_loss: 0.1171 - article_loss: 0.1743 - gender_accuracy: 0.9910 - usage_accuracy: 0.9492 - article_accuracy: 0.9320
# Epoch 68: val_loss did not improve from 0.96224
# 436/436 [==============================] - 432s 993ms/step - loss: 0.8765 - gender_loss: 0.0277 - usage_loss: 0.1171 - article_loss: 0.1743 - gender_accuracy: 0.9910 - usage_accuracy: 0.9492 - article_accuracy: 0.9320 - val_loss: 0.9707 - val_gender_loss: 0.0344 - val_usage_loss: 0.1369 - val_article_loss: 0.2049 - val_gender_accuracy: 0.9880 - val_usage_accuracy: 0.9407 - val_article_accuracy: 0.9232 - lr: 6.2500e-06
# Epoch 69/70
# 436/436 [==============================] - ETA: 0s - loss: 0.8914 - gender_loss: 0.0295 - usage_loss: 0.1154 - article_loss: 0.1810 - gender_accuracy: 0.9904 - usage_accuracy: 0.9512 - article_accuracy: 0.9289
# Epoch 69: val_loss did not improve from 0.96224
# 436/436 [==============================] - 428s 984ms/step - loss: 0.8914 - gender_loss: 0.0295 - usage_loss: 0.1154 - article_loss: 0.1810 - gender_accuracy: 0.9904 - usage_accuracy: 0.9512 - article_accuracy: 0.9289 - val_loss: 1.0059 - val_gender_loss: 0.0339 - val_usage_loss: 0.1489 - val_article_loss: 0.2173 - val_gender_accuracy: 0.9882 - val_usage_accuracy: 0.9375 - val_article_accuracy: 0.9194 - lr: 6.2500e-06
# Epoch 70/70
# 436/436 [==============================] - ETA: 0s - loss: 0.8897 - gender_loss: 0.0307 - usage_loss: 0.1151 - article_loss: 0.1794 - gender_accuracy: 0.9901 - usage_accuracy: 0.9512 - article_accuracy: 0.9303
# Epoch 70: val_loss did not improve from 0.96224
#
# Epoch 70: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 436/436 [==============================] - 429s 987ms/step - loss: 0.8897 - gender_loss: 0.0307 - usage_loss: 0.1151 - article_loss: 0.1794 - gender_accuracy: 0.9901 - usage_accuracy: 0.9512 - article_accuracy: 0.9303 - val_loss: 0.9670 - val_gender_loss: 0.0339 - val_usage_loss: 0.1358 - val_article_loss: 0.2046 - val_gender_accuracy: 0.9882 - val_usage_accuracy: 0.9412 - val_article_accuracy: 0.9237 - lr: 6.2500e-06

# %%
# Evaluasi model pada gambar berkualitas rendah yang disimulasikan
validation_steps = len(val_df) // BATCH_SIZE
results = evaluate_on_degraded_images(robust_model, None, validation_steps)
# Out:
# Found 3495 validated image filenames.
#
# ===== EVALUASI MODEL PADA GAMBAR BERKUALITAS RENDAH =====
# 109/109 [==============================] - 81s 742ms/step - loss: 3.1535 - gender_loss: 0.5273 - usage_loss: 0.1710 - article_loss: 0.7870 - gender_accuracy: 0.9183 - usage_accuracy: 0.9286 - article_accuracy: 0.7944
#
# Loss: 3.1535000801086426
# Gender Accuracy: 91.83%
# Usage Accuracy: 92.86%
# Article Accuracy: 79.44%

# %%
# Visualisasi augmentasi
visualize_augmentations()
# Out:
# Found 5 validated image filenames.

# %%
# Plot training history
plt.figure(figsize=(15, 10))
    
# Plot loss
plt.subplot(2, 2, 1)
plt.plot(robust_history['loss'], label='Training Loss')
plt.plot(robust_history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
    
# Plot accuracy untuk gender
plt.subplot(2, 2, 2)
plt.plot(robust_history['gender_accuracy'], label='Training Accuracy')
plt.plot(robust_history['val_gender_accuracy'], label='Validation Accuracy')
plt.title('Gender Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
    
# Plot accuracy untuk usage
plt.subplot(2, 2, 3)
plt.plot(robust_history['usage_accuracy'], label='Training Accuracy')
plt.plot(robust_history['val_usage_accuracy'], label='Validation Accuracy')
plt.title('Usage Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
    
# Plot accuracy untuk article
plt.subplot(2, 2, 4)
plt.plot(robust_history['article_accuracy'], label='Training Accuracy')
plt.plot(robust_history['val_article_accuracy'], label='Validation Accuracy')
plt.title('Article Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
    
plt.tight_layout()
plt.savefig('training_history.png')
plt.show()
    
print("\nTraining and evaluation complete!")
# Out:
# Training and evaluation complete!

# %%
import pickle

# Simpan LabelEncoder ke file pickle
with open('le_gender.pkl', 'wb') as f:
    pickle.dump(le_gender, f)

with open('le_usage.pkl', 'wb') as f:
    pickle.dump(le_usage, f)

with open('le_article.pkl', 'wb') as f:
    pickle.dump(le_article, f)

print("LabelEncoder berhasil disimpan.")
# Out:
# LabelEncoder berhasil disimpan.
